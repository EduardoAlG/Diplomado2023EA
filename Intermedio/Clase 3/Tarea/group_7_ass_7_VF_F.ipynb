# %% [markdown]
# # Assigment 7

# %%
#!pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\elias\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\elias\anaconda3\lib\site-packages (from scipy) (1.20.3)

# %% [markdown]
# ## Part I
# 1. Each group must create their branch named group_#_ass_7_2024 (group_1_ass_7_2024) and save their results in the Assignment_7 folder. Name your JN like your branch.
# 2. Import the data located at this link. This dataset comes from this link. It has information on all the geolocated health establishments in Cajamarca.
# 3. Import the district's centroids data. It has the latitude and longitude of every district in Peru.
# 4. Use these datasets and find the closest health establishment to Cajamarca district centroids. Use euclidian distance between points. DO NOT USE GOOGLE API. IT WILL BE VERY EXPENSIVE For each district, there should be only one health establishment.
# 5. Use Google API Directions to find the driving travel time and distance from health establishments to district centroids. Set driving as the value of the parameter mode and Monday 4pm as departure_time. Include information on the three options of the traffic_model variable: best_guess, pessimistic, and optimistic. The final data frame output should look like the table

# %% [markdown]
# ### 0) Importing necessary packages

# %%
# For sending GET requests from the API
import requests

# For saving access tokens and for file management when creating and adding to the dataset
import os

# For dealing with json responses we receive from the API
import json

# For displaying the data after
import pandas as pd
import numpy as np

# For saving the response data in CSV format
import csv

# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata

#To add wait time between requests
import time
import requests

# Other packages
import urllib.request
from tqdm import tqdm_notebook as tqdm
import re
from scipy.spatial import distance

# To make graphics 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1) Creating DF of the closest health establishment to Cajamarca district centroids

# %% [markdown]
# #### 1.1 Getting the necessary files

# %%
# Getting the files from the "_data" folder 
file1_path = r"../../../_data/cajamarca_data_helth_estb.xlsx" 

# Creating Data Frames
c_estb = pd.read_excel(file1_path)
c_estb
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# 1                           JAEN
# 2                           JAEN
# 3                           JAEN
# 4                           JAEN
# ...                          ...
# 1187                      SOCOTA
# 1188                      SOCOTA
# 1189                      SOCOTA
# 1190                      SOCOTA
# 1191                 SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1     OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2     CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4     OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
# ...                                                 ...        ...       ...
# 1187  CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471 -6.292044
# 1188  OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080 -6.279960
# 1189  OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640 -6.266560
# 1190  OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210 -6.267210
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo  ...  CCPP  NOMBPROV CCDI           NOMBDIST  \
# 0           636  ...     8      JAEN    1               JAEN
# 1           636  ...     8      JAEN    1               JAEN
# 2           636  ...     8      JAEN    1               JAEN
# 3           636  ...     8      JAEN    1               JAEN
# 4           636  ...     8      JAEN    1               JAEN
# ...         ...  ...   ...       ...  ...                ...
# 1187        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1188        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1189        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1190        627  ...     6   CUTERVO   10  SAN LUIS DE LUCMA
# 1191        650  ...     2     BAGUA    5              IMAZA
#
#                 CAPITAL  UBIGEO IDPROV CODIGO  CNT_CCPP         DESCRIPCIO
# 0                  JAEN   60801    608  60801       108               JAEN
# 1                  JAEN   60801    608  60801       108               JAEN
# 2                  JAEN   60801    608  60801       108               JAEN
# 3                  JAEN   60801    608  60801       108               JAEN
# 4                  JAEN   60801    608  60801       108               JAEN
# ...                 ...     ...    ...    ...       ...                ...
# 1187  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1188  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1189  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1190  SAN LUIS DE LUCMA   60610    606  60610        19  SAN LUIS DE LUCMA
# 1191           CHIRIACO   10205    102  10205       159              IMAZA
#
# [1192 rows x 23 columns]

# %%
# Getting the files from the "_data" folder
file2_path = r"../../../_data/peru_districts_centroids.xlsx"

# Creating Data Frames
d_centro = pd.read_excel(file2_path)
d_centro = d_centro.loc[d_centro['NOMBDEP'] == 'CAJAMARCA']
d_centro['Centroid'] = list(zip(d_centro['Centroid_Latitude'], d_centro['Centroid_Longitude']))

d_centro
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0        6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1        6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2        6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3        6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4        6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...    ...        ...   ...         ...   ...           ...              ...
# 1644     6  CAJAMARCA     3    CELENDIN     8      OXAMARCA         OXAMARCA
# 1645     6  CAJAMARCA     3    CELENDIN     9     SOROCHUCO        SOROCHUCO
# 1743     6  CAJAMARCA     8        JAEN    10    SAN FELIPE       SAN FELIPE
# 1744     6  CAJAMARCA     8        JAEN     6    LAS PIRIAS       LAS PIRIAS
# 1762     6  CAJAMARCA     6     CUTERVO     6     PIMPINGOS        PIMPINGOS
#
#       UBIGEO  IDPROV  CODIGO  Centroid_Latitude  Centroid_Longitude  \
# 0      60504     605   60504          -7.364304          -78.917689
# 1      61105     611   61105          -7.038039          -79.003318
# 2      61109     611   61109          -6.926718          -79.131435
# 3      61110     611   61110          -7.117978          -79.160968
# 4      61203     612   61203          -7.159046          -78.873084
# ...      ...     ...     ...                ...                 ...
# 1644   60308     603   60308          -7.059289          -78.061333
# 1645   60309     603   60309          -6.934215          -78.297182
# 1743   60810     608   60810          -5.786477          -79.310211
# 1744   60806     608   60806          -5.636342          -78.849590
# 1762   60606     606   60606          -6.070895          -78.768292
#
#                                       Centroid
# 0      (-7.364304037451185, -78.9176888857091)
# 1     (-7.038039308001461, -79.00331840461457)
# 2     (-6.926717799126992, -79.13143524251483)
# 3     (-7.117978014363154, -79.16096822944561)
# 4      (-7.159045931055743, -78.8730841197766)
# ...                                        ...
# 1644  (-7.059288980121174, -78.06133279004958)
# 1645  (-6.934214997604489, -78.29718227998802)
# 1743  (-5.786477227250232, -79.31021142229889)
# 1744  (-5.636341962042768, -78.84958991537201)
# 1762   (-6.07089520466843, -78.76829226789994)
#
# [127 rows x 13 columns]

# %% [markdown]
# #### 1.2 Getting DF with the list of closest health establishment

# %%
health_establishment = c_estb[ ['latitud','longitud'] ].values
centroids = d_centro[ ['Centroid_Latitude', 'Centroid_Longitude' ] ].values

# %%
# Function to calculate Euclidean distance
def euclidean_dist(point1, point2):
    return distance.euclidean(point1, point2)

# %%
# Iterating through each district centroid and find the closest health establishment
closest_he = []

for district_coord in centroids:
    distances = [euclidean_dist(district_coord, health_coord) for health_coord in health_establishment]
    closest_index = distances.index(min(distances))
    closest_he.append({
        'Centroid': tuple(district_coord),
        'Closest_Health_Establishment': c_estb.iloc[closest_index]
    })
closest_he
# Out:
# [{'Centroid': (-7.364304037451185, -78.9176888857091),
#   'Closest_Health_Establishment': id_eess                                                       5348
#   codigo_renaes                                                 4554
#   categoria                                                      I-2
#   nombre                                                  TOTORILLAS
#   diresa                                                   CAJAMARCA
#   red                                                      CONTUMAZA
#   direccion        OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ...
#   longitud                                                -78.930011
#   latitud                                                  -7.353468
#   id_ubigeo                                                      613
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             5
#   NOMBPROV                                                 CONTUMAZA
#   CCDI                                                             4
#   NOMBDIST                                                  GUZMANGO
#   CAPITAL                                                   GUZMANGO
#   UBIGEO                                                       60504
#   IDPROV                                                         605
#   CODIGO                                                       60504
#   CNT_CCPP                                                        50
#   DESCRIPCIO                                                GUZMANGO
#   Name: 441, dtype: object},
#  {'Centroid': (-7.038039308001461, -79.00331840461457),
#   'Closest_Health_Establishment': id_eess                      21765
#   codigo_renaes                 4575
#   categoria                      I-2
#   nombre                    EL PRADO
#   diresa                   CAJAMARCA
#   red                     SAN MIGUEL
#   direccion        DISTRITO EL PRADO
#   longitud                 -79.00941
#   latitud                  -7.033193
#   id_ubigeo                      666
#   ind                              1
#   CCDD                             6
#   NOMBDEP                  CAJAMARCA
#   CCPP                            11
#   NOMBPROV                SAN MIGUEL
#   CCDI                             5
#   NOMBDIST                  EL PRADO
#   CAPITAL                   EL PRADO
#   UBIGEO                       61105
#   IDPROV                         611
#   CODIGO                       61105
#   CNT_CCPP                        15
#   DESCRIPCIO                EL PRADO
#   Name: 414, dtype: object},
#  {'Centroid': (-6.926717799126992, -79.13143524251483),
#   'Closest_Health_Establishment': id_eess                                                       7184
#   codigo_renaes                                                 4557
#   categoria                                                      I-2
#   nombre                                                      NIEPOS
#   diresa                                                   CAJAMARCA
#   red                                                     SAN MIGUEL
#   direccion        OTROS DISTRITO NIEPOS DISTRITO NIEPOS PROVINCI...
#   longitud                                                -79.128402
#   latitud                                                  -6.926729
#   id_ubigeo                                                      670
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            11
#   NOMBPROV                                                SAN MIGUEL
#   CCDI                                                             9
#   NOMBDIST                                                    NIEPOS
#   CAPITAL                                                     NIEPOS
#   UBIGEO                                                       61109
#   IDPROV                                                         611
#   CODIGO                                                       61109
#   CNT_CCPP                                                        41
#   DESCRIPCIO                                                  NIEPOS
#   Name: 443, dtype: object},
#  {'Centroid': (-7.117978014363154, -79.16096822944561),
#   'Closest_Health_Establishment': id_eess                                                      13171
#   codigo_renaes                                                 4535
#   categoria                                                      I-1
#   nombre                                                    EL SAUCE
#   diresa                                                   CAJAMARCA
#   red                                                     SAN MIGUEL
#   direccion        OTROS LOCALIDAD EL SAUCE DISTRITO SAN GREGORIO...
#   longitud                                                 -79.12735
#   latitud                                                   -7.06395
#   id_ubigeo                                                      671
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            11
#   NOMBPROV                                                SAN MIGUEL
#   CCDI                                                            10
#   NOMBDIST                                              SAN GREGORIO
#   CAPITAL                                               SAN GREGORIO
#   UBIGEO                                                       61110
#   IDPROV                                                         611
#   CODIGO                                                       61110
#   CNT_CCPP                                                        48
#   DESCRIPCIO                                            SAN GREGORIO
#   Name: 405, dtype: object},
#  {'Centroid': (-7.159045931055743, -78.8730841197766),
#   'Closest_Health_Establishment': id_eess                                                       5349
#   codigo_renaes                                                 4585
#   categoria                                                      I-1
#   nombre                                      SAN LUIS BAJO - GRANDE
#   diresa                                                   CAJAMARCA
#   red                                                      SAN PABLO
#   direccion        JIRÓN JR. LIMA S/N NÚMERO S/N DISTRITO SAN LUI...
#   longitud                                                -78.869062
#   latitud                                                  -7.156648
#   id_ubigeo                                                      677
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            12
#   NOMBPROV                                                 SAN PABLO
#   CCDI                                                             3
#   NOMBDIST                                                  SAN LUIS
#   CAPITAL                                            SAN LUIS GRANDE
#   UBIGEO                                                       61203
#   IDPROV                                                         612
#   CODIGO                                                       61203
#   CNT_CCPP                                                         9
#   DESCRIPCIO                                                SAN LUIS
#   Name: 472, dtype: object},
#  {'Centroid': (-6.230898091099231, -78.56969883536429),
#   'Closest_Health_Establishment': id_eess                                                      13976
#   codigo_renaes                                                 7179
#   categoria                                                      I-1
#   nombre                                                  CHACRERIAS
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE CHACRERIAS COMUNIDAD DE CHA...
#   longitud                                                -78.577313
#   latitud                                                  -6.229452
#   id_ubigeo                                                      622
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                             5
#   NOMBDIST                                                 LA RAMADA
#   CAPITAL                                                  LA RAMADA
#   UBIGEO                                                       60605
#   IDPROV                                                         606
#   CODIGO                                                       60605
#   CNT_CCPP                                                        17
#   DESCRIPCIO                                               LA RAMADA
#   Name: 1163, dtype: object},
#  {'Centroid': (-7.077465094056442, -78.56111128956503),
#   'Closest_Health_Establishment': id_eess                                                      25604
#   codigo_renaes                                                 4640
#   categoria                                                      I-3
#   nombre                                                  LA TULPUNA
#   diresa                                                   CAJAMARCA
#   red                                                      CAJAMARCA
#   direccion        AVENIDA AV. ALFONSO UGARTE S/N S/N AV. ALFONSO...
#   longitud                                                 -78.55323
#   latitud                                                   -7.06213
#   id_ubigeo                                                      563
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             1
#   NOMBPROV                                                 CAJAMARCA
#   CCDI                                                             1
#   NOMBDIST                                                 CAJAMARCA
#   CAPITAL                                                  CAJAMARCA
#   UBIGEO                                                       60101
#   IDPROV                                                         601
#   CODIGO                                                       60101
#   CNT_CCPP                                                       126
#   DESCRIPCIO                                               CAJAMARCA
#   Name: 526, dtype: object},
#  {'Centroid': (-6.224067513358646, -78.7422789712748),
#   'Closest_Health_Establishment': id_eess                                                      18471
#   codigo_renaes                                                 6940
#   categoria                                                      I-1
#   nombre                                                     PAJONAL
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE PAJONAL COMUNIDAD DE PAJONA...
#   longitud                                                -78.741223
#   latitud                                                  -6.221281
#   id_ubigeo                                                      625
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                            13
#   NOMBDIST                                               SANTO TOMAS
#   CAPITAL                                                SANTO TOMAS
#   UBIGEO                                                       60613
#   IDPROV                                                         606
#   CODIGO                                                       60613
#   CNT_CCPP                                                        40
#   DESCRIPCIO                                             SANTO TOMAS
#   Name: 1055, dtype: object},
#  {'Centroid': (-6.174218113399612, -78.60009249414134),
#   'Closest_Health_Establishment': id_eess                                                      26339
#   codigo_renaes                                                 7103
#   categoria                                                      I-1
#   nombre                                      SANTA ROSA DE SAN JUAN
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE SANTA ROSA COMUNIDAD DE SAN...
#   longitud                                                 -78.60362
#   latitud                                                   -6.17102
#   id_ubigeo                                                      626
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                             9
#   NOMBDIST                                       SAN JUAN DE CUTERVO
#   CAPITAL                                        SAN JUAN DE CUTERVO
#   UBIGEO                                                       60609
#   IDPROV                                                         606
#   CODIGO                                                       60609
#   CNT_CCPP                                                        23
#   DESCRIPCIO                                     SAN JUAN DE CUTERVO
#   Name: 1170, dtype: object},
#  {'Centroid': (-6.279101100284, -78.57875268121131),
#   'Closest_Health_Establishment': id_eess                                                      16451
#   codigo_renaes                                                 6870
#   categoria                                                      I-1
#   nombre                                        SANTA ROSA DEL TINGO
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI...
#   longitud                                                 -78.59764
#   latitud                                                   -6.26656
#   id_ubigeo                                                      627
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                            10
#   NOMBDIST                                         SAN LUIS DE LUCMA
#   CAPITAL                                          SAN LUIS DE LUCMA
#   UBIGEO                                                       60610
#   IDPROV                                                         606
#   CODIGO                                                       60610
#   CNT_CCPP                                                        19
#   DESCRIPCIO                                       SAN LUIS DE LUCMA
#   Name: 1189, dtype: object},
#  {'Centroid': (-6.257949078684879, -78.84272293558155),
#   'Closest_Health_Establishment': id_eess                                                      15497
#   codigo_renaes                                                 5005
#   categoria                                                      I-1
#   nombre                                    SANTA ROSA DE LA CAPILLA
#   diresa                                                   CAJAMARCA
#   red                                                        CUTERVO
#   direccion        OTROS COMUNIDAD DE SANTA ROSA DE LA CAPILLA CO...
#   longitud                                                -78.839945
#   latitud                                                  -6.272358
#   id_ubigeo                                                      629
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                            12
#   NOMBDIST                               SANTO DOMINGO DE LA CAPILLA
#   CAPITAL                                SANTO DOMINGO DE LA CAPILLA
#   UBIGEO                                                       60612
#   IDPROV                                                         606
#   CODIGO                                                       60612
#   CNT_CCPP                                                        28
#   DESCRIPCIO                             SANTO DOMINGO DE LA CAPILLA
#   Name: 1133, dtype: object},
#  {'Centroid': (-6.118075749420057, -78.67710453728564),
#   'Closest_Health_Establishment': id_eess                                                      16458
#   codigo_renaes                                                 7750
#   categoria                                                      I-1
#   nombre                                                     TAYALES
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE TAYALES COMUNIDAD DE TAYALE...
#   longitud                                                -78.654733
#   latitud                                                  -6.117938
#   id_ubigeo                                                      630
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                            13
#   NOMBDIST                                               SANTO TOMAS
#   CAPITAL                                                SANTO TOMAS
#   UBIGEO                                                       60613
#   IDPROV                                                         606
#   CODIGO                                                       60613
#   CNT_CCPP                                                        40
#   DESCRIPCIO                                             SANTO TOMAS
#   Name: 1057, dtype: object},
#  {'Centroid': (-6.287362417254426, -78.69671913212724),
#   'Closest_Health_Establishment': id_eess                                                       8592
#   codigo_renaes                                                 6937
#   categoria                                                      I-1
#   nombre                                             MINAS DE SOCOTA
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        OTROS COMUNIDAD DE MINAS COMUNIDAD DE MINAS SO...
#   longitud                                                 -78.69043
#   latitud                                                   -6.29289
#   id_ubigeo                                                      631
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                            14
#   NOMBDIST                                                    SOCOTA
#   CAPITAL                                                     SOCOTA
#   UBIGEO                                                       60614
#   IDPROV                                                         606
#   CODIGO                                                       60614
#   CNT_CCPP                                                        37
#   DESCRIPCIO                                                  SOCOTA
#   Name: 1179, dtype: object},
#  {'Centroid': (-6.570579571483123, -78.18705795503254),
#   'Closest_Health_Establishment': id_eess                                                      21960
#   codigo_renaes                                                 4479
#   categoria                                                      I-1
#   nombre                                                     CHUMUCH
#   diresa                                                   CAJAMARCA
#   red                                                       CELENDIN
#   direccion        OTROS COMUNIDAD CHUMUCH DISTRITO CHUMUCH PROVI...
#   longitud                                                -78.198371
#   latitud                                                  -6.603466
#   id_ubigeo                                                      580
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             3
#   NOMBPROV                                                  CELENDIN
#   CCDI                                                             2
#   NOMBDIST                                                   CHUMUCH
#   CAPITAL                                                    CHUMUCH
#   UBIGEO                                                       60302
#   IDPROV                                                         603
#   CODIGO                                                       60302
#   CNT_CCPP                                                        23
#   DESCRIPCIO                                                 CHUMUCH
#   Name: 326, dtype: object},
#  {'Centroid': (-6.487693638144822, -78.28551672740241),
#   'Closest_Health_Establishment': id_eess                                                      18468
#   codigo_renaes                                                 6757
#   categoria                                                      I-1
#   nombre                                                      CANDEN
#   diresa                                                   CAJAMARCA
#   red                                                       CELENDIN
#   direccion        OTROS LOCALIDAD CANDEN DISTRITO CORTEGANA PROV...
#   longitud                                                -78.304103
#   latitud                                                  -6.458809
#   id_ubigeo                                                      581
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             3
#   NOMBPROV                                                  CELENDIN
#   CCDI                                                             3
#   NOMBDIST                                                 CORTEGANA
#   CAPITAL                                        CHIMUCH (CORTEGANA)
#   UBIGEO                                                       60303
#   IDPROV                                                         603
#   CODIGO                                                       60303
#   CNT_CCPP                                                        61
#   DESCRIPCIO                                               CORTEGANA
#   Name: 309, dtype: object},
#  {'Centroid': (-6.337966578285939, -78.57580091635643),
#   'Closest_Health_Establishment': id_eess                                                      20300
#   codigo_renaes                                                 4750
#   categoria                                                      I-2
#   nombre                                                      ANGUIA
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS DISTRITO DE ANGUIA DISTRITO DE ANGUIA AN...
#   longitud                                                -78.606175
#   latitud                                                  -6.341027
#   id_ubigeo                                                      592
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                             2
#   NOMBDIST                                                    ANGUIA
#   CAPITAL                                                     ANGUIA
#   UBIGEO                                                       60402
#   IDPROV                                                         604
#   CODIGO                                                       60402
#   CNT_CCPP                                                        17
#   DESCRIPCIO                                                  ANGUIA
#   Name: 903, dtype: object},
#  {'Centroid': (-6.42507988722172, -78.70803618399547),
#   'Closest_Health_Establishment': id_eess                                                      21965
#   codigo_renaes                                                 4758
#   categoria                                                      I-2
#   nombre                                                      TUGUZA
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS COMUNIDAD TUGUSA COMUNIDAD TUGUSA CHIGUI...
#   longitud                                                -78.700471
#   latitud                                                  -6.433063
#   id_ubigeo                                                      594
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                             4
#   NOMBDIST                                                 CHIGUIRIP
#   CAPITAL                                                  CHIGUIRIP
#   UBIGEO                                                       60404
#   IDPROV                                                         604
#   CODIGO                                                       60404
#   CNT_CCPP                                                        18
#   DESCRIPCIO                                               CHIGUIRIP
#   Name: 911, dtype: object},
#  {'Centroid': (-6.28458920942883, -78.44814198981383),
#   'Closest_Health_Establishment': id_eess                                                      15624
#   codigo_renaes                                                 4702
#   categoria                                                      I-1
#   nombre                                         SAN JOSE DE CHIMBAN
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS COMUNIDAD SAN JOSE DE CHIMBAN COMUNIDAD ...
#   longitud                                                -78.481509
#   latitud                                                  -6.293367
#   id_ubigeo                                                      595
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                             5
#   NOMBDIST                                                   CHIMBAN
#   CAPITAL                                                    CHIMBAN
#   UBIGEO                                                       60405
#   IDPROV                                                         604
#   CODIGO                                                       60405
#   CNT_CCPP                                                        28
#   DESCRIPCIO                                                 CHIMBAN
#   Name: 806, dtype: object},
#  {'Centroid': (-6.483027838660707, -78.85225970740323),
#   'Closest_Health_Establishment': id_eess                                                      22918
#   codigo_renaes                                                 4698
#   categoria                                                      I-1
#   nombre                                                      SEGUES
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS COMUNIDAD SEGUES COMUNIDAD SEGUES COCHAB...
#   longitud                                                 -78.82662
#   latitud                                                   -6.47196
#   id_ubigeo                                                      597
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                             7
#   NOMBDIST                                                COCHABAMBA
#   CAPITAL                                                 COCHABAMBA
#   UBIGEO                                                       60407
#   IDPROV                                                         604
#   CODIGO                                                       60407
#   CNT_CCPP                                                        35
#   DESCRIPCIO                                              COCHABAMBA
#   Name: 799, dtype: object},
#  {'Centroid': (-6.574491015719826, -78.72756806509733),
#   'Closest_Health_Establishment': id_eess                                                      10767
#   codigo_renaes                                                 4685
#   categoria                                                      I-1
#   nombre                                                   LA SINRRA
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS COMUNIDAD LA SINRRA DISTRITO LAJAS PROVI...
#   longitud                                                 -78.73645
#   latitud                                                   -6.57357
#   id_ubigeo                                                      600
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                            10
#   NOMBDIST                                                     LAJAS
#   CAPITAL                                                      LAJAS
#   UBIGEO                                                       60410
#   IDPROV                                                         604
#   CODIGO                                                       60410
#   CNT_CCPP                                                        41
#   DESCRIPCIO                                                   LAJAS
#   Name: 780, dtype: object},
#  {'Centroid': (-6.18419525009336, -78.47818241083328),
#   'Closest_Health_Establishment': id_eess                                                       9251
#   codigo_renaes                                                 4692
#   categoria                                                      I-2
#   nombre                                                        PION
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS COMUNIDAD PION COMUNIDAD PION PION CHOTA...
#   longitud                                                -78.481833
#   latitud                                                  -6.178873
#   id_ubigeo                                                      604
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                            14
#   NOMBDIST                                                      PION
#   CAPITAL                                                       PION
#   UBIGEO                                                       60414
#   IDPROV                                                         604
#   CODIGO                                                       60414
#   CNT_CCPP                                                        14
#   DESCRIPCIO                                                    PION
#   Name: 792, dtype: object},
#  {'Centroid': (-6.456833769681386, -79.37598617970025),
#   'Closest_Health_Establishment': id_eess                                                      21966
#   codigo_renaes                                                 4781
#   categoria                                                      I-3
#   nombre                                                    TOCMOCHE
#   diresa                                                   CAJAMARCA
#   red                                                          CHOTA
#   direccion        OTROS DISTRITO TOCMOCHE DISTRITO TOCMOCHE TOCM...
#   longitud                                                 -79.36031
#   latitud                                                  -6.411979
#   id_ubigeo                                                      608
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             4
#   NOMBPROV                                                     CHOTA
#   CCDI                                                            18
#   NOMBDIST                                                  TOCMOCHE
#   CAPITAL                                                   TOCMOCHE
#   UBIGEO                                                       60418
#   IDPROV                                                         604
#   CODIGO                                                       60418
#   CNT_CCPP                                                        35
#   DESCRIPCIO                                                TOCMOCHE
#   Name: 944, dtype: object},
#  {'Centroid': (-6.8042771604382, -78.73384164479626),
#   'Closest_Health_Establishment': id_eess                                                      21589
#   codigo_renaes                                                 4606
#   categoria                                                      I-1
#   nombre                                               QUILCATE ALTO
#   diresa                                                   CAJAMARCA
#   red                                                     SAN MIGUEL
#   direccion        OTROS CPM QUILCATE ALTO CPM QUILCATE ALTO CATI...
#   longitud                                                  -78.7313
#   latitud                                                   -6.81692
#   id_ubigeo                                                      665
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            11
#   NOMBPROV                                                SAN MIGUEL
#   CCDI                                                             4
#   NOMBDIST                                                  CATILLUC
#   CAPITAL                                                   CATILLUC
#   UBIGEO                                                       61104
#   IDPROV                                                         611
#   CODIGO                                                       61104
#   CNT_CCPP                                                        23
#   DESCRIPCIO                                                CATILLUC
#   Name: 514, dtype: object},
#  {'Centroid': (-6.627556466156622, -78.94191466046652),
#   'Closest_Health_Establishment': id_eess                                                      19454
#   codigo_renaes                                                 4813
#   categoria                                                      I-4
#   nombre                                                  SANTA CRUZ
#   diresa                                                   CAJAMARCA
#   red                                                     SANTA CRUZ
#   direccion        AVENIDA AV. ZARUMILLA S/N NÚMERO S/N DISTRITO ...
#   longitud                                                -78.943336
#   latitud                                                  -6.630679
#   id_ubigeo                                                      679
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            13
#   NOMBPROV                                                SANTA CRUZ
#   CCDI                                                             1
#   NOMBDIST                                                SANTA CRUZ
#   CAPITAL                                  SANTA CRUZ DE SUCCHABAMBA
#   UBIGEO                                                       61301
#   IDPROV                                                         613
#   CODIGO                                                       61301
#   CNT_CCPP                                                        52
#   DESCRIPCIO                                              SANTA CRUZ
#   Name: 967, dtype: object},
#  {'Centroid': (-6.664009037035801, -78.80972226391866),
#   'Closest_Health_Establishment': id_eess                                                      10078
#   codigo_renaes                                                 4818
#   categoria                                                      I-2
#   nombre                                                   ANDABAMBA
#   diresa                                                   CAJAMARCA
#   red                                                     SANTA CRUZ
#   direccion        OTROS COMUNIDAD ANDABAMBA DISTRITO ANDABAMBA P...
#   longitud                                                 -78.81947
#   latitud                                                   -6.66291
#   id_ubigeo                                                      680
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                            13
#   NOMBPROV                                                SANTA CRUZ
#   CCDI                                                             2
#   NOMBDIST                                                 ANDABAMBA
#   CAPITAL                                                  ANDABAMBA
#   UBIGEO                                                       61302
#   IDPROV                                                         613
#   CODIGO                                                       61302
#   CNT_CCPP                                                        11
#   DESCRIPCIO                                               ANDABAMBA
#   Name: 974, dtype: object},
#  {'Centroid': (-5.140405077923568, -79.00789460996974),
#   'Closest_Health_Establishment': id_eess                                                      10759
#   codigo_renaes                                                 4267
#   categoria                                                      I-4
#   nombre                                                 SAN IGNACIO
#   diresa                                                   CAJAMARCA
#   red                                                    SAN IGNACIO
#   direccion        AVENIDA AV. ABELARDO QUIÑONES S/N NÚMERO S/N D...
#   longitud                                                -79.003002
#   latitud                                                   -5.14467
#   id_ubigeo                                                      648
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             9
#   NOMBPROV                                               SAN IGNACIO
#   CCDI                                                             1
#   NOMBDIST                                               SAN IGNACIO
#   CAPITAL                                                SAN IGNACIO
#   UBIGEO                                                       60901
#   IDPROV                                                         609
#   CODIGO                                                       60901
#   CNT_CCPP                                                        99
#   DESCRIPCIO                                             SAN IGNACIO
#   Name: 181, dtype: object},
#  {'Centroid': (-5.307553228839856, -78.88245718685589),
#   'Closest_Health_Establishment': id_eess                                                      10916
#   codigo_renaes                                                 4274
#   categoria                                                      I-3
#   nombre                                                    CHIRINOS
#   diresa                                                   CAJAMARCA
#   red                                                    SAN IGNACIO
#   direccion        OTROS ALTO PERU S/N NÚMERO S/N DISTRITO CHIRIN...
#   longitud                                                -78.901724
#   latitud                                                  -5.302773
#   id_ubigeo                                                      649
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             9
#   NOMBPROV                                               SAN IGNACIO
#   CCDI                                                             2
#   NOMBDIST                                                  CHIRINOS
#   CAPITAL                                                   CHIRINOS
#   UBIGEO                                                       60902
#   IDPROV                                                         609
#   CODIGO                                                       60902
#   CNT_CCPP                                                        84
#   DESCRIPCIO                                                CHIRINOS
#   Name: 210, dtype: object},
#  {'Centroid': (-5.09652405211401, -78.71529057820497),
#   'Closest_Health_Establishment': id_eess                                                      12206
#   codigo_renaes                                                 4284
#   categoria                                                      I-3
#   nombre                                     EL PORVENIR DE HUARANGO
#   diresa                                                   CAJAMARCA
#   red                                                    SAN IGNACIO
#   direccion        OTROS DISTRITO EL HUARANGO DISTRITO EL HUARANG...
#   longitud                                                 -78.75058
#   latitud                                                   -5.16398
#   id_ubigeo                                                      650
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             9
#   NOMBPROV                                               SAN IGNACIO
#   CCDI                                                             3
#   NOMBDIST                                                  HUARANGO
#   CAPITAL                                                   HUARANGO
#   UBIGEO                                                       60903
#   IDPROV                                                         609
#   CODIGO                                                       60903
#   CNT_CCPP                                                        96
#   DESCRIPCIO                                                HUARANGO
#   Name: 223, dtype: object},
#  {'Centroid': (-5.38963741943043, -78.97348368601949),
#   'Closest_Health_Establishment': id_eess                                                      21404
#   codigo_renaes                                                 4290
#   categoria                                                      I-3
#   nombre                                                    RUMIPITE
#   diresa                                                   CAJAMARCA
#   red                                                    SAN IGNACIO
#   direccion        OTROS COMUNIDAD DE RUMIPITE COMUNIDAD DE RUMIP...
#   longitud                                                 -78.97517
#   latitud                                                   -5.38766
#   id_ubigeo                                                      651
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
# ...
#   NOMBPROV                                                 CAJAMARCA
#   CCDI                                                             5
#   NOMBDIST                                                 ENCAÑADA
#   CAPITAL                                                  ENCAÑADA
#   UBIGEO                                                       60105
#   IDPROV                                                         601
#   CODIGO                                                       60105
#   CNT_CCPP                                                       110
#   DESCRIPCIO                                               ENCAÑADA
#   Name: 497, dtype: object},
#  {'Centroid': (-7.567687463603137, -78.25332891600632),
#   'Closest_Health_Establishment': id_eess                                                       3296
#   codigo_renaes                                                 4513
#   categoria                                                      I-2
#   nombre                                                   ALGAMARCA
#   diresa                                                   CAJAMARCA
#   red                                                      CAJABAMBA
#   direccion        OTROS CPM SAN JOSE DE ALGAMARCA DISTRITO CACHA...
#   longitud                                                -78.246737
#   latitud                                                  -7.607261
#   id_ubigeo                                                      576
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             2
#   NOMBPROV                                                 CAJABAMBA
#   CCDI                                                             2
#   NOMBDIST                                                  CACHACHI
#   CAPITAL                                                   CACHACHI
#   UBIGEO                                                       60202
#   IDPROV                                                         602
#   CODIGO                                                       60202
#   CNT_CCPP                                                       183
#   DESCRIPCIO                                                CACHACHI
#   Name: 381, dtype: object},
#  {'Centroid': (-7.530122419973073, -78.09113520240439),
#   'Closest_Health_Establishment': id_eess                                                      26115
#   codigo_renaes                                                 4516
#   categoria                                                      I-2
#   nombre                                                       OTUTO
#   diresa                                                   CAJAMARCA
#   red                                                      CAJABAMBA
#   direccion        OTROS CASERIO CONDEBAMBA S/N NÚMERO S/N DISTRI...
#   longitud                                                -78.069807
#   latitud                                                  -7.527459
#   id_ubigeo                                                      577
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             2
#   NOMBPROV                                                 CAJABAMBA
#   CCDI                                                             3
#   NOMBDIST                                                CONDEBAMBA
#   CAPITAL                                                     CAUDAY
#   UBIGEO                                                       60203
#   IDPROV                                                         602
#   CODIGO                                                       60203
#   CNT_CCPP                                                        61
#   DESCRIPCIO                                              CONDEBAMBA
#   Name: 389, dtype: object},
#  {'Centroid': (-7.474385184657658, -77.90631489984364),
#   'Closest_Health_Establishment': id_eess                                                      15353
#   codigo_renaes                                                 4519
#   categoria                                                      I-2
#   nombre                                     SAN JUAN DE LLUCHUBAMBA
#   diresa                                                   CAJAMARCA
#   red                                                      CAJABAMBA
#   direccion        OTROS LOCALIDAD SAN JUAN DISTRITO SITACOCHA PR...
#   longitud                                                -77.880669
#   latitud                                                  -7.463787
#   id_ubigeo                                                      578
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             2
#   NOMBPROV                                                 CAJABAMBA
#   CCDI                                                             4
#   NOMBDIST                                                 SITACOCHA
#   CAPITAL                                                LLUCHUBAMBA
#   UBIGEO                                                       60204
#   IDPROV                                                         602
#   CODIGO                                                       60204
#   CNT_CCPP                                                        75
#   DESCRIPCIO                                               SITACOCHA
#   Name: 395, dtype: object},
#  {'Centroid': (-6.919895067629336, -78.15877251548687),
#   'Closest_Health_Establishment': id_eess                                                      21961
#   codigo_renaes                                                 4488
#   categoria                                                      I-2
#   nombre                                                 JOSE GALVEZ
#   diresa                                                   CAJAMARCA
#   red                                                       CELENDIN
#   direccion        JIRÓN JR. EL RECUERDO N° 105 DISTRITO JOSE GAL...
#   longitud                                                 -78.13082
#   latitud                                                  -6.929531
#   id_ubigeo                                                      584
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             3
#   NOMBPROV                                                  CELENDIN
#   CCDI                                                             6
#   NOMBDIST                                               JOSE GALVEZ
#   CAPITAL                                                 HUACAPAMPA
#   UBIGEO                                                       60306
#   IDPROV                                                         603
#   CODIGO                                                       60306
#   CNT_CCPP                                                        24
#   DESCRIPCIO                                             JOSE GALVEZ
#   Name: 341, dtype: object},
#  {'Centroid': (-7.059288980121174, -78.06133279004958),
#   'Closest_Health_Establishment': id_eess                                                       1068
#   codigo_renaes                                                 9049
#   categoria                                                      I-1
#   nombre                                                   LA QUINUA
#   diresa                                                   CAJAMARCA
#   red                                                       CELENDIN
#   direccion        OTROS COMUNIDAD LA QUINUA DISTRITO OXAMARCA PR...
#   longitud                                                 -78.05464
#   latitud                                                  -7.072427
#   id_ubigeo                                                      586
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             3
#   NOMBPROV                                                  CELENDIN
#   CCDI                                                             8
#   NOMBDIST                                                  OXAMARCA
#   CAPITAL                                                   OXAMARCA
#   UBIGEO                                                       60308
#   IDPROV                                                         603
#   CODIGO                                                       60308
#   CNT_CCPP                                                        62
#   DESCRIPCIO                                                OXAMARCA
#   Name: 339, dtype: object},
#  {'Centroid': (-6.934214997604489, -78.29718227998802),
#   'Closest_Health_Establishment': id_eess                                                      17649
#   codigo_renaes                                                 4594
#   categoria                                                      I-1
#   nombre                                                 LA CHORRERA
#   diresa                                                   CAJAMARCA
#   red                                                       CELENDIN
#   direccion        OTROS LOCALIDAD LA CHORRERA LOCALIDAD LA CHORR...
#   longitud                                                -78.315067
#   latitud                                                  -6.950057
#   id_ubigeo                                                      587
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             3
#   NOMBPROV                                                  CELENDIN
#   CCDI                                                             9
#   NOMBDIST                                                 SOROCHUCO
#   CAPITAL                                                  SOROCHUCO
#   UBIGEO                                                       60309
#   IDPROV                                                         603
#   CODIGO                                                       60309
#   CNT_CCPP                                                        80
#   DESCRIPCIO                                               SOROCHUCO
#   Name: 290, dtype: object},
#  {'Centroid': (-5.786477227250232, -79.31021142229889),
#   'Closest_Health_Establishment': id_eess                                                      21403
#   codigo_renaes                                                 4254
#   categoria                                                      I-3
#   nombre                                                  SAN FELIPE
#   diresa                                                   CAJAMARCA
#   red                                                           JAEN
#   direccion        OTROS COMUNIDAD SAN FELIPE COMUNIDAD SAN FELIP...
#   longitud                                                -79.312835
#   latitud                                                  -5.770258
#   id_ubigeo                                                      645
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             8
#   NOMBPROV                                                      JAEN
#   CCDI                                                            10
#   NOMBDIST                                                SAN FELIPE
#   CAPITAL                                                 SAN FELIPE
#   UBIGEO                                                       60810
#   IDPROV                                                         608
#   CODIGO                                                       60810
#   CNT_CCPP                                                        84
#   DESCRIPCIO                                              SAN FELIPE
#   Name: 172, dtype: object},
#  {'Centroid': (-5.636341962042768, -78.84958991537201),
#   'Closest_Health_Establishment': id_eess                                                      13022
#   codigo_renaes                                                 4245
#   categoria                                                      I-3
#   nombre                                          LAS PIRIAS DE JAEN
#   diresa                                                   CAJAMARCA
#   red                                                           JAEN
#   direccion        PLAZA PLAZA DE ARMAS PIRIAS S/N S/N PLAZA DE A...
#   longitud                                                -78.852416
#   latitud                                                  -5.627073
#   id_ubigeo                                                      641
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             8
#   NOMBPROV                                                      JAEN
#   CCDI                                                             6
#   NOMBDIST                                                LAS PIRIAS
#   CAPITAL                                                 LAS PIRIAS
#   UBIGEO                                                       60806
#   IDPROV                                                         608
#   CODIGO                                                       60806
#   CNT_CCPP                                                        38
#   DESCRIPCIO                                              LAS PIRIAS
#   Name: 154, dtype: object},
#  {'Centroid': (-6.07089520466843, -78.76829226789994),
#   'Closest_Health_Establishment': id_eess                                                       6464
#   codigo_renaes                                                 5012
#   categoria                                                      I-3
#   nombre                                                   PIMPINCOS
#   diresa                                                   CAJAMARCA
#   red                                                         SOCOTA
#   direccion        JIRÓN JR. COMERCIO S/N NÚMERO S/N DISTRITO PIM...
#   longitud                                                -78.756689
#   latitud                                                  -6.060707
#   id_ubigeo                                                      623
#   ind                                                              1
#   CCDD                                                             6
#   NOMBDEP                                                  CAJAMARCA
#   CCPP                                                             6
#   NOMBPROV                                                   CUTERVO
#   CCDI                                                             6
#   NOMBDIST                                                 PIMPINGOS
#   CAPITAL                                                  PIMPINGOS
#   UBIGEO                                                       60606
#   IDPROV                                                         606
#   CODIGO                                                       60606
#   CNT_CCPP                                                        36
#   DESCRIPCIO                                               PIMPINGOS
#   Name: 1142, dtype: object}]

# %%
# Creating a new dataframe with the closest health establishments
aux_df = pd.DataFrame(closest_he)

df_expanded = pd.concat([aux_df.drop(['Closest_Health_Establishment'], axis=1),
                                    aux_df['Closest_Health_Establishment'].apply(pd.Series)], axis=1)

# %%
df = pd.merge(d_centro, df_expanded, left_on='Centroid', right_on='Centroid', how='inner', suffixes=('_orig', '_closest'))
df
# Out:
#      CCDD_orig NOMBDEP_orig  CCPP_orig NOMBPROV_orig  CCDI_orig NOMBDIST_orig  \
# 0            6    CAJAMARCA          5     CONTUMAZA          4      GUZMANGO
# 1            6    CAJAMARCA         11    SAN MIGUEL          5      EL PRADO
# 2            6    CAJAMARCA         11    SAN MIGUEL          9        NIEPOS
# 3            6    CAJAMARCA         11    SAN MIGUEL         10  SAN GREGORIO
# 4            6    CAJAMARCA         12     SAN PABLO          3      SAN LUIS
# ..         ...          ...        ...           ...        ...           ...
# 122          6    CAJAMARCA          3      CELENDIN          8      OXAMARCA
# 123          6    CAJAMARCA          3      CELENDIN          9     SOROCHUCO
# 124          6    CAJAMARCA          8          JAEN         10    SAN FELIPE
# 125          6    CAJAMARCA          8          JAEN          6    LAS PIRIAS
# 126          6    CAJAMARCA          6       CUTERVO          6     PIMPINGOS
#
#         CAPITAL_orig  UBIGEO_orig  IDPROV_orig  CODIGO_orig  ...  \
# 0           GUZMANGO        60504          605        60504  ...
# 1           EL PRADO        61105          611        61105  ...
# 2             NIEPOS        61109          611        61109  ...
# 3       SAN GREGORIO        61110          611        61110  ...
# 4    SAN LUIS GRANDE        61203          612        61203  ...
# ..               ...          ...          ...          ...  ...
# 122         OXAMARCA        60308          603        60308  ...
# 123        SOROCHUCO        60309          603        60309  ...
# 124       SAN FELIPE        60810          608        60810  ...
# 125       LAS PIRIAS        60806          608        60806  ...
# 126        PIMPINGOS        60606          606        60606  ...
#
#      CCPP_closest  NOMBPROV_closest CCDI_closest  NOMBDIST_closest  \
# 0               5         CONTUMAZA            4          GUZMANGO
# 1              11        SAN MIGUEL            5          EL PRADO
# 2              11        SAN MIGUEL            9            NIEPOS
# 3              11        SAN MIGUEL           10      SAN GREGORIO
# 4              12         SAN PABLO            3          SAN LUIS
# ..            ...               ...          ...               ...
# 122             3          CELENDIN            8          OXAMARCA
# 123             3          CELENDIN            9         SOROCHUCO
# 124             8              JAEN           10        SAN FELIPE
# 125             8              JAEN            6        LAS PIRIAS
# 126             6           CUTERVO            6         PIMPINGOS
#
#      CAPITAL_closest UBIGEO_closest IDPROV_closest CODIGO_closest CNT_CCPP  \
# 0           GUZMANGO          60504            605          60504       50
# 1           EL PRADO          61105            611          61105       15
# 2             NIEPOS          61109            611          61109       41
# 3       SAN GREGORIO          61110            611          61110       48
# 4    SAN LUIS GRANDE          61203            612          61203        9
# ..               ...            ...            ...            ...      ...
# 122         OXAMARCA          60308            603          60308       62
# 123        SOROCHUCO          60309            603          60309       80
# 124       SAN FELIPE          60810            608          60810       84
# 125       LAS PIRIAS          60806            608          60806       38
# 126        PIMPINGOS          60606            606          60606       36
#
#        DESCRIPCIO
# 0        GUZMANGO
# 1        EL PRADO
# 2          NIEPOS
# 3    SAN GREGORIO
# 4        SAN LUIS
# ..            ...
# 122      OXAMARCA
# 123     SOROCHUCO
# 124    SAN FELIPE
# 125    LAS PIRIAS
# 126     PIMPINGOS
#
# [127 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['CCDD_orig', 'NOMBDEP_orig', 'CCPP_orig', 'NOMBPROV_orig', 'CCDI_orig',
#        'NOMBDIST_orig', 'CAPITAL_orig', 'UBIGEO_orig', 'IDPROV_orig',
#        'CODIGO_orig', 'Centroid_Latitude', 'Centroid_Longitude', 'Centroid',
#        'id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
#        'direccion', 'longitud', 'latitud', 'id_ubigeo', 'ind', 'CCDD_closest',
#        'NOMBDEP_closest', 'CCPP_closest', 'NOMBPROV_closest', 'CCDI_closest',
#        'NOMBDIST_closest', 'CAPITAL_closest', 'UBIGEO_closest',
#        'IDPROV_closest', 'CODIGO_closest', 'CNT_CCPP', 'DESCRIPCIO'],
#       dtype='object')

# %% [markdown]
# ### 5) Use Google API Directions to find the driving travel time and distance from health establishments to district centroids.

# %%
#We create the origin variable, which unites the latitude and longitude of the health centers
d_centro['origin'] = d_centro['Centroid_Latitude'].astype(str) + ',' + d_centro['Centroid_Longitude'].astype(str)
d_centro
# Out:
#       CCDD    NOMBDEP  CCPP    NOMBPROV  CCDI      NOMBDIST          CAPITAL  \
# 0        6  CAJAMARCA     5   CONTUMAZA     4      GUZMANGO         GUZMANGO
# 1        6  CAJAMARCA    11  SAN MIGUEL     5      EL PRADO         EL PRADO
# 2        6  CAJAMARCA    11  SAN MIGUEL     9        NIEPOS           NIEPOS
# 3        6  CAJAMARCA    11  SAN MIGUEL    10  SAN GREGORIO     SAN GREGORIO
# 4        6  CAJAMARCA    12   SAN PABLO     3      SAN LUIS  SAN LUIS GRANDE
# ...    ...        ...   ...         ...   ...           ...              ...
# 1644     6  CAJAMARCA     3    CELENDIN     8      OXAMARCA         OXAMARCA
# 1645     6  CAJAMARCA     3    CELENDIN     9     SOROCHUCO        SOROCHUCO
# 1743     6  CAJAMARCA     8        JAEN    10    SAN FELIPE       SAN FELIPE
# 1744     6  CAJAMARCA     8        JAEN     6    LAS PIRIAS       LAS PIRIAS
# 1762     6  CAJAMARCA     6     CUTERVO     6     PIMPINGOS        PIMPINGOS
#
#       UBIGEO  IDPROV  CODIGO  Centroid_Latitude  Centroid_Longitude  \
# 0      60504     605   60504          -7.364304          -78.917689
# 1      61105     611   61105          -7.038039          -79.003318
# 2      61109     611   61109          -6.926718          -79.131435
# 3      61110     611   61110          -7.117978          -79.160968
# 4      61203     612   61203          -7.159046          -78.873084
# ...      ...     ...     ...                ...                 ...
# 1644   60308     603   60308          -7.059289          -78.061333
# 1645   60309     603   60309          -6.934215          -78.297182
# 1743   60810     608   60810          -5.786477          -79.310211
# 1744   60806     608   60806          -5.636342          -78.849590
# 1762   60606     606   60606          -6.070895          -78.768292
#
#                                       Centroid  \
# 0      (-7.364304037451185, -78.9176888857091)
# 1     (-7.038039308001461, -79.00331840461457)
# 2     (-6.926717799126992, -79.13143524251483)
# 3     (-7.117978014363154, -79.16096822944561)
# 4      (-7.159045931055743, -78.8730841197766)
# ...                                        ...
# 1644  (-7.059288980121174, -78.06133279004958)
# 1645  (-6.934214997604489, -78.29718227998802)
# 1743  (-5.786477227250232, -79.31021142229889)
# 1744  (-5.636341962042768, -78.84958991537201)
# 1762   (-6.07089520466843, -78.76829226789994)
#
#                                      origin
# 0      -7.364304037451185,-78.9176888857091
# 1     -7.038039308001461,-79.00331840461457
# 2     -6.926717799126992,-79.13143524251483
# 3     -7.117978014363154,-79.16096822944561
# 4      -7.159045931055743,-78.8730841197766
# ...                                     ...
# 1644  -7.059288980121174,-78.06133279004958
# 1645  -6.934214997604489,-78.29718227998802
# 1743  -5.786477227250232,-79.31021142229889
# 1744  -5.636341962042768,-78.84958991537201
# 1762   -6.07089520466843,-78.76829226789994
#
# [127 rows x 14 columns]

# %%
#We create the destination variable, which unites the latitude and longitude of the centroids of the districts
c_estb['destinations'] = c_estb['latitud'].astype(str) + ',' + c_estb['longitud'].astype(str)
c_estb
# Out:
#       id_eess  codigo_renaes categoria                nombre     diresa  \
# 0        9439           4210      II-1            GRAL. JAEN  CAJAMARCA
# 1       27242           4211       I-4           MORRO SOLAR  CAJAMARCA
# 2       22911           4212       I-3             MAGLLANAL  CAJAMARCA
# 3        9242           4213       I-3             FILA ALTA  CAJAMARCA
# 4       26418           4214       I-1          LAS NARANJAS  CAJAMARCA
# ...       ...            ...       ...                   ...        ...
# 1187    21625           5038       I-3  SAN LUIS DE LA LUCMA  CAJAMARCA
# 1188     8179           6853       I-1            SAIREPAMPA  CAJAMARCA
# 1189    16451           6870       I-1  SANTA ROSA DEL TINGO  CAJAMARCA
# 1190     3040           7048       I-1             SEXESHITA  CAJAMARCA
# 1191    26156           6995       I-1              PISAGUAS  CAJAMARCA
#
#                              red  \
# 0     NO PERTENECE A NINGUNA RED
# 1                           JAEN
# 2                           JAEN
# 3                           JAEN
# 4                           JAEN
# ...                          ...
# 1187                      SOCOTA
# 1188                      SOCOTA
# 1189                      SOCOTA
# 1190                      SOCOTA
# 1191                 SAN IGNACIO
#
#                                               direccion   longitud   latitud  \
# 0     AVENIDA AV. PAKAMAUROS S/N S/N AV. PAKAMAUROS ... -78.804711 -5.706214
# 1     OTROS ALFREDO BASTOS Nº 630 ALFREDO BASTOS Nº ... -78.811920 -5.710600
# 2     CALLE CALLE LAS ALMENDRA CDRA. 4 S/N S/N CALLE... -78.817266 -5.707647
# 3     OTROS COMUNIDAD FILA ALTA COMUNIDAD FILA ALTA ... -78.791643 -5.739184
# 4     OTROS COMUNIDAD DE LAS NARANJAS COMUNIDAD DE L... -78.846347 -5.745295
# ...                                                 ...        ...       ...
# 1187  CARRETERA CARRETERA LUCMA SOCOTA DISTRITO SAN ... -78.607471 -6.292044
# 1188  OTROS COMUNIDAD DE SAIREPAMPA DISTRITO SAN LUI... -78.631080 -6.279960
# 1189  OTROS COMUNIDAD DE SANTA ROSA DEL TINGO DISTRI... -78.597640 -6.266560
# 1190  OTROS COMUNIDAD DE SEXESHITA DISTRITO SAN LUIS... -78.627210 -6.267210
# 1191  OTROS COMUNIDAD DE PISAGUAS DISTRITO HUARANGO ... -78.640093 -5.248693
#
#       id_ubigeo  ...  NOMBPROV  CCDI           NOMBDIST            CAPITAL  \
# 0           636  ...      JAEN     1               JAEN               JAEN
# 1           636  ...      JAEN     1               JAEN               JAEN
# 2           636  ...      JAEN     1               JAEN               JAEN
# 3           636  ...      JAEN     1               JAEN               JAEN
# 4           636  ...      JAEN     1               JAEN               JAEN
# ...         ...  ...       ...   ...                ...                ...
# 1187        627  ...   CUTERVO    10  SAN LUIS DE LUCMA  SAN LUIS DE LUCMA
# 1188        627  ...   CUTERVO    10  SAN LUIS DE LUCMA  SAN LUIS DE LUCMA
# 1189        627  ...   CUTERVO    10  SAN LUIS DE LUCMA  SAN LUIS DE LUCMA
# 1190        627  ...   CUTERVO    10  SAN LUIS DE LUCMA  SAN LUIS DE LUCMA
# 1191        650  ...     BAGUA     5              IMAZA           CHIRIACO
#
#      UBIGEO  IDPROV CODIGO CNT_CCPP         DESCRIPCIO  \
# 0     60801     608  60801      108               JAEN
# 1     60801     608  60801      108               JAEN
# 2     60801     608  60801      108               JAEN
# 3     60801     608  60801      108               JAEN
# 4     60801     608  60801      108               JAEN
# ...     ...     ...    ...      ...                ...
# 1187  60610     606  60610       19  SAN LUIS DE LUCMA
# 1188  60610     606  60610       19  SAN LUIS DE LUCMA
# 1189  60610     606  60610       19  SAN LUIS DE LUCMA
# 1190  60610     606  60610       19  SAN LUIS DE LUCMA
# 1191  10205     102  10205      159              IMAZA
#
#                   destinations
# 0     -5.70621441,-78.80471119
# 1            -5.7106,-78.81192
# 2     -5.70764748,-78.81726576
# 3         -5.739184,-78.791643
# 4         -5.745295,-78.846347
# ...                        ...
# 1187  -6.29204385,-78.60747056
# 1188        -6.27996,-78.63108
# 1189        -6.26656,-78.59764
# 1190        -6.26721,-78.62721
# 1191  -5.24869333,-78.64009333
#
# [1192 rows x 24 columns]

# %%
# We create the data frame with the data of health facilities and centroids of districts united by the respective ubigeo
df_EESS_Dist = pd.merge(d_centro, c_estb, on='UBIGEO', how='inner')
df_EESS_Dist
# Out:
#       CCDD_x  NOMBDEP_x  CCPP_x  NOMBPROV_x  CCDI_x NOMBDIST_x  CAPITAL_x  \
# 0          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 1          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 2          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 3          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 4          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# ...      ...        ...     ...         ...     ...        ...        ...
# 1185       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 1186       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 1187       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 1188       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 1189       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
#
#       UBIGEO  IDPROV_x  CODIGO_x  ...  CCPP_y  NOMBPROV_y CCDI_y NOMBDIST_y  \
# 0      60504       605     60504  ...       5   CONTUMAZA      4   GUZMANGO
# 1      60504       605     60504  ...       5   CONTUMAZA      4   GUZMANGO
# 2      61105       611     61105  ...      11  SAN MIGUEL      5   EL PRADO
# 3      61105       611     61105  ...      11  SAN MIGUEL      5   EL PRADO
# 4      61105       611     61105  ...      11  SAN MIGUEL      5   EL PRADO
# ...      ...       ...       ...  ...     ...         ...    ...        ...
# 1185   60606       606     60606  ...       6     CUTERVO      6  PIMPINGOS
# 1186   60606       606     60606  ...       6     CUTERVO      6  PIMPINGOS
# 1187   60606       606     60606  ...       6     CUTERVO      6  PIMPINGOS
# 1188   60606       606     60606  ...       6     CUTERVO      6  PIMPINGOS
# 1189   60606       606     60606  ...       6     CUTERVO      6  PIMPINGOS
#
#       CAPITAL_y  IDPROV_y CODIGO_y CNT_CCPP DESCRIPCIO  \
# 0      GUZMANGO       605    60504       50   GUZMANGO
# 1      GUZMANGO       605    60504       50   GUZMANGO
# 2      EL PRADO       611    61105       15   EL PRADO
# 3      EL PRADO       611    61105       15   EL PRADO
# 4      EL PRADO       611    61105       15   EL PRADO
# ...         ...       ...      ...      ...        ...
# 1185  PIMPINGOS       606    60606       36  PIMPINGOS
# 1186  PIMPINGOS       606    60606       36  PIMPINGOS
# 1187  PIMPINGOS       606    60606       36  PIMPINGOS
# 1188  PIMPINGOS       606    60606       36  PIMPINGOS
# 1189  PIMPINGOS       606    60606       36  PIMPINGOS
#
#                   destinations
# 0     -7.38409169,-78.89679828
# 1      -7.3534676,-78.93001098
# 2       -7.10131833,-79.010525
# 3           -7.10447,-78.98587
# 4          -7.033193,-79.00941
# ...                        ...
# 1185        -6.10259,-78.79857
# 1186  -6.10896577,-78.75397426
# 1187   -6.1227371,-78.72649756
# 1188  -6.07393899,-78.80657398
# 1189  -6.12254822,-78.76394727
#
# [1190 rows x 37 columns]

# %%
#We verify that the renaes code variable is unique for the health centers
num_unique_values = df_EESS_Dist['codigo_renaes'].nunique()

if num_unique_values == 1:
    print("La variable 'codigo_renaes' no tiene valores únicos.")
else:
    print("La variable 'codigo_renaes' tiene valores únicos.")
# Out:
# La variable 'codigo_renaes' tiene valores únicos.

# %%
# Create a new DataFrame by copying the original
df_EESS_Dist_1 = df_EESS_Dist.copy()
# Add a new column called 'trafic' with the value 'optimistic'
df_EESS_Dist_1['trafic'] = 'optimistic'
df_EESS_Dist_1['code_trafic'] = '1'

# Create a new DataFrame by copying the original
df_EESS_Dist_2 = df_EESS_Dist.copy()
# Add a new column called 'trafic' with the value 'pessimistic'
df_EESS_Dist_2['trafic'] = 'pessimistic'
df_EESS_Dist_2['code_trafic'] = '2'

# Create a new DataFrame by copying the original
df_EESS_Dist_3 = df_EESS_Dist.copy()
# Add a new column called 'trafic' with the value 'best_guess'
df_EESS_Dist_3['trafic'] = 'best_guess'
df_EESS_Dist_3['code_trafic'] = '3'

#We obtain the final data to calculate the distance and time according to the type of traffic.
df_EESS_Distrito = pd.concat([df_EESS_Dist_1, df_EESS_Dist_2, df_EESS_Dist_3], axis=0, ignore_index=True)

df_EESS_Distrito
# Out:
#       CCDD_x  NOMBDEP_x  CCPP_x  NOMBPROV_x  CCDI_x NOMBDIST_x  CAPITAL_x  \
# 0          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 1          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 2          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 3          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 4          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# ...      ...        ...     ...         ...     ...        ...        ...
# 3565       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3566       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3567       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3568       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3569       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
#
#       UBIGEO  IDPROV_x  CODIGO_x  ...  CCDI_y  NOMBDIST_y  CAPITAL_y IDPROV_y  \
# 0      60504       605     60504  ...       4    GUZMANGO   GUZMANGO      605
# 1      60504       605     60504  ...       4    GUZMANGO   GUZMANGO      605
# 2      61105       611     61105  ...       5    EL PRADO   EL PRADO      611
# 3      61105       611     61105  ...       5    EL PRADO   EL PRADO      611
# 4      61105       611     61105  ...       5    EL PRADO   EL PRADO      611
# ...      ...       ...       ...  ...     ...         ...        ...      ...
# 3565   60606       606     60606  ...       6   PIMPINGOS  PIMPINGOS      606
# 3566   60606       606     60606  ...       6   PIMPINGOS  PIMPINGOS      606
# 3567   60606       606     60606  ...       6   PIMPINGOS  PIMPINGOS      606
# 3568   60606       606     60606  ...       6   PIMPINGOS  PIMPINGOS      606
# 3569   60606       606     60606  ...       6   PIMPINGOS  PIMPINGOS      606
#
#       CODIGO_y  CNT_CCPP DESCRIPCIO              destinations      trafic  \
# 0        60504        50   GUZMANGO  -7.38409169,-78.89679828  optimistic
# 1        60504        50   GUZMANGO   -7.3534676,-78.93001098  optimistic
# 2        61105        15   EL PRADO    -7.10131833,-79.010525  optimistic
# 3        61105        15   EL PRADO        -7.10447,-78.98587  optimistic
# 4        61105        15   EL PRADO       -7.033193,-79.00941  optimistic
# ...        ...       ...        ...                       ...         ...
# 3565     60606        36  PIMPINGOS        -6.10259,-78.79857  best_guess
# 3566     60606        36  PIMPINGOS  -6.10896577,-78.75397426  best_guess
# 3567     60606        36  PIMPINGOS   -6.1227371,-78.72649756  best_guess
# 3568     60606        36  PIMPINGOS  -6.07393899,-78.80657398  best_guess
# 3569     60606        36  PIMPINGOS  -6.12254822,-78.76394727  best_guess
#
#      code_trafic
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 3565           3
# 3566           3
# 3567           3
# 3568           3
# 3569           3
#
# [3570 rows x 39 columns]

# %%
# Generate lists for district code, trafic code, source address and destination address.
combination = df_EESS_Distrito['codigo_renaes'].tolist()
origin = df_EESS_Distrito['origin'].tolist()
destination = df_EESS_Distrito['destinations'].tolist()
trafic = df_EESS_Distrito['trafic'].tolist()
code = df_EESS_Distrito['code_trafic'].tolist()

# %%
# Generate dictionary to store data
data_distance_EESS = {} 

# Loop to generate information about geolocations of health establishment and district
distance_EESS_Dist = np.zeros(shape=(len(combination),4), dtype =float)
i=0

for c,o,d,t,p in tqdm(list(zip(combination, origin, destination, trafic, code))):
    try:
        
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

        ## Fixed Parameters
        # Paramaters
        traffic_model = t  

        # Departure time
        departure_time= '1707148800'

        # We choose the driving option
        mode = 'driving'

        # key
        api_key = 'AIzaSyC31_X8VEXuGuP9JzujTcZmGxgoQZ3noEI'

        # region Perú = pe
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # Concatenate strings
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        
        # We save the json file information in each location of the matrix
        
        distance_EESS_Dist[i][0] = c
        distance_EESS_Dist[i][1] = legs['distance']['value']
        distance_EESS_Dist[i][2] = legs['duration_in_traffic']['value']
        distance_EESS_Dist[i][3] = p
        
        i=i+1
        
        my_keys = ['distance', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance_EESS[c] = info 
    
    except Exception as e:
        
        # If you do not have information, generate nan data to fill the coordinates of the matrix
        distance_EESS_Dist[i][0] = c
        distance_EESS_Dist[i][1] = "nan"
        distance_EESS_Dist[i][2] = "nan"
        distance_EESS_Dist[i][3] = p
        
        i=i+1
        
        print(c)
# Out:
# C:\Users\U S U A R I O\AppData\Local\Temp\ipykernel_8456\998106599.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   
# 4515.0
# 4527.0
# 4528.0
# 4529.0
# 4530.0
# 18165.0
# 4516.0
# 4517.0
# 4518.0
# 4526.0
# 4531.0
# 28459.0
# 4519.0
# 4520.0
# 4521.0
# 4522.0
# 4523.0
# 4524.0
# 4486.0
# 4488.0
# 4483.0
# 4484.0
# 9046.0
# 9049.0
# 4469.0
# 4470.0
# 4594.0
# 9029.0
# 9083.0
# 11149.0
# 11152.0
# 12714.0
# 4254.0
# 4255.0
# 24940.0
# 4245.0
# 4246.0
# 5012.0
# 5013.0
# 5014.0
# 5015.0
# 5016.0
# 5018.0
# 5024.0
# 6867.0
# 11068.0

# %%
#We generate a data frame with the calculated distance and time
distance_time_trafic = pd.DataFrame(distance_EESS_Dist, columns = ['codigo_renaes', 'travel_distance','travel_time', 'code_trafic'])
distance_time_trafic
# Out:
#       codigo_renaes  travel_distance  travel_time  code_trafic
# 0            4553.0              NaN          NaN          1.0
# 1            4554.0              NaN          NaN          1.0
# 2            4540.0              NaN          NaN          1.0
# 3            4573.0              NaN          NaN          1.0
# 4            4575.0              NaN          NaN          1.0
# ...             ...              ...          ...          ...
# 3565         5016.0              NaN          NaN          3.0
# 3566         5018.0              NaN          NaN          3.0
# 3567         5024.0              NaN          NaN          3.0
# 3568         6867.0              NaN          NaN          3.0
# 3569        11068.0              NaN          NaN          3.0
#
# [3570 rows x 4 columns]

# %%
#We adjust the type of variable to be able to merge of df
df_EESS_Distrito['codigo_renaes'] = df_EESS_Distrito['codigo_renaes'].astype(float)
df_EESS_Distrito['code_trafic'] = df_EESS_Distrito['code_trafic'].astype(float)

# %%
df_final_time_dist = pd.merge(df_EESS_Distrito, distance_time_trafic, on=['codigo_renaes', 'code_trafic'], how='inner')
df_final_time_dist
# Out:
#       CCDD_x  NOMBDEP_x  CCPP_x  NOMBPROV_x  CCDI_x NOMBDIST_x  CAPITAL_x  \
# 0          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 1          6  CAJAMARCA       5   CONTUMAZA       4   GUZMANGO   GUZMANGO
# 2          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 3          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# 4          6  CAJAMARCA      11  SAN MIGUEL       5   EL PRADO   EL PRADO
# ...      ...        ...     ...         ...     ...        ...        ...
# 3565       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3566       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3567       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3568       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
# 3569       6  CAJAMARCA       6     CUTERVO       6  PIMPINGOS  PIMPINGOS
#
#       UBIGEO  IDPROV_x  CODIGO_x  ...  CAPITAL_y  IDPROV_y CODIGO_y CNT_CCPP  \
# 0      60504       605     60504  ...   GUZMANGO       605    60504       50
# 1      60504       605     60504  ...   GUZMANGO       605    60504       50
# 2      61105       611     61105  ...   EL PRADO       611    61105       15
# 3      61105       611     61105  ...   EL PRADO       611    61105       15
# 4      61105       611     61105  ...   EL PRADO       611    61105       15
# ...      ...       ...       ...  ...        ...       ...      ...      ...
# 3565   60606       606     60606  ...  PIMPINGOS       606    60606       36
# 3566   60606       606     60606  ...  PIMPINGOS       606    60606       36
# 3567   60606       606     60606  ...  PIMPINGOS       606    60606       36
# 3568   60606       606     60606  ...  PIMPINGOS       606    60606       36
# 3569   60606       606     60606  ...  PIMPINGOS       606    60606       36
#
#       DESCRIPCIO              destinations      trafic code_trafic  \
# 0       GUZMANGO  -7.38409169,-78.89679828  optimistic         1.0
# 1       GUZMANGO   -7.3534676,-78.93001098  optimistic         1.0
# 2       EL PRADO    -7.10131833,-79.010525  optimistic         1.0
# 3       EL PRADO        -7.10447,-78.98587  optimistic         1.0
# 4       EL PRADO       -7.033193,-79.00941  optimistic         1.0
# ...          ...                       ...         ...         ...
# 3565   PIMPINGOS        -6.10259,-78.79857  best_guess         3.0
# 3566   PIMPINGOS  -6.10896577,-78.75397426  best_guess         3.0
# 3567   PIMPINGOS   -6.1227371,-78.72649756  best_guess         3.0
# 3568   PIMPINGOS  -6.07393899,-78.80657398  best_guess         3.0
# 3569   PIMPINGOS  -6.12254822,-78.76394727  best_guess         3.0
#
#      travel_distance travel_time
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 3565             NaN         NaN
# 3566             NaN         NaN
# 3567             NaN         NaN
# 3568             NaN         NaN
# 3569             NaN         NaN
#
# [3570 rows x 41 columns]

# %%
#We keep the necessary variables and adjust the name of the final variables
columnas_deseadas = ['id_eess', 'codigo_renaes', 'categoria', 'nombre', 'diresa', 'red',
                      'direccion', 'longitud', 'latitud', 'id_ubigeo', 'UBIGEO', 'CCDD_x',
                      'NOMBDEP_x', 'CCPP_x', 'NOMBPROV_x', 'CCDI_x', 'NOMBDIST_x', 'CAPITAL_x',
                      'NOMBDIST_y', 'Centroid_Longitude', 'Centroid_Latitude',
                      'travel_time', 'travel_distance', 'trafic']

df_Dist_EESS = df_final_time_dist[columnas_deseadas]

new_names = {'CCDD_x': 'CCDD', 'NOMBDEP_x': 'NOMBDEP', 'CCPP_x': 'CCPP', 'NOMBPROV_x': 'NOMBPROV', 'CCDI_x': 'CCDI', 'NOMBDIST_x': 'NOMBDIST', 'CAPITAL_x': 'CAPITAL', 'NOMBDIST_y': 'District', 'Centroid_Latitude': 'Dist_Centroid_Latitude', 'Centroid_Longitude': 'Dist_Centroid_Longitude'}
df_Dist_EESS = df_Dist_EESS.rename(columns=new_names)

df_Dist_EESS
# Out:
#       id_eess  codigo_renaes categoria          nombre     diresa         red  \
# 0       13172         4553.0       I-2        GUZMANGO  CAJAMARCA   CONTUMAZA
# 1        5348         4554.0       I-2      TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       18927         4540.0       I-1        EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       13899         4573.0       I-2      LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       21765         4575.0       I-2        EL PRADO  CAJAMARCA  SAN MIGUEL
# ...       ...            ...       ...             ...        ...         ...
# 3565    24913         5016.0       I-1        PANDALLE  CAJAMARCA      SOCOTA
# 3566    10080         5018.0       I-1        EL PALTO  CAJAMARCA      SOCOTA
# 3567    13036         5024.0       I-1      LANCHEPATA  CAJAMARCA      SOCOTA
# 3568    13500         6867.0       I-1  LIBERTAD LIMON  CAJAMARCA      SOCOTA
# 3569    24108        11068.0       I-1          PUCALA  CAJAMARCA      SOCOTA
#
#                                               direccion   longitud   latitud  \
# 0     JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1     OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2     OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3     OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                     DISTRITO EL PRADO -79.009410 -7.033193
# ...                                                 ...        ...       ...
# 3565  OTROS COMUNIDAD DE PANDALLE DISTRITO PIMPINGOS... -78.798570 -6.102590
# 3566  OTROS CASERIO EL PALTO S/N NÚMERO S/N DISTRITO... -78.753974 -6.108966
# 3567  OTROS COMUNIDAD LANCHEPATA DISTRITO SANTO TOMA... -78.726498 -6.122737
# 3568  OTROS COMUNIDAD LIBERTAD LIMON COMUNIDAD LIBER... -78.806574 -6.073939
# 3569  OTROS CPM PUCALA DISTRITO PIMPINGOS PROVINCIA ... -78.763947 -6.122548
#
#       id_ubigeo  ...    NOMBPROV  CCDI   NOMBDIST    CAPITAL   District  \
# 0           613  ...   CONTUMAZA     4   GUZMANGO   GUZMANGO   GUZMANGO
# 1           613  ...   CONTUMAZA     4   GUZMANGO   GUZMANGO   GUZMANGO
# 2           666  ...  SAN MIGUEL     5   EL PRADO   EL PRADO   EL PRADO
# 3           666  ...  SAN MIGUEL     5   EL PRADO   EL PRADO   EL PRADO
# 4           666  ...  SAN MIGUEL     5   EL PRADO   EL PRADO   EL PRADO
# ...         ...  ...         ...   ...        ...        ...        ...
# 3565        623  ...     CUTERVO     6  PIMPINGOS  PIMPINGOS  PIMPINGOS
# 3566        623  ...     CUTERVO     6  PIMPINGOS  PIMPINGOS  PIMPINGOS
# 3567        630  ...     CUTERVO     6  PIMPINGOS  PIMPINGOS  PIMPINGOS
# 3568        623  ...     CUTERVO     6  PIMPINGOS  PIMPINGOS  PIMPINGOS
# 3569        623  ...     CUTERVO     6  PIMPINGOS  PIMPINGOS  PIMPINGOS
#
#       Dist_Centroid_Longitude Dist_Centroid_Latitude travel_time  \
# 0                  -78.917689              -7.364304         NaN
# 1                  -78.917689              -7.364304         NaN
# 2                  -79.003318              -7.038039         NaN
# 3                  -79.003318              -7.038039         NaN
# 4                  -79.003318              -7.038039         NaN
# ...                       ...                    ...         ...
# 3565               -78.768292              -6.070895         NaN
# 3566               -78.768292              -6.070895         NaN
# 3567               -78.768292              -6.070895         NaN
# 3568               -78.768292              -6.070895         NaN
# 3569               -78.768292              -6.070895         NaN
#
#      travel_distance      trafic
# 0                NaN  optimistic
# 1                NaN  optimistic
# 2                NaN  optimistic
# 3                NaN  optimistic
# 4                NaN  optimistic
# ...              ...         ...
# 3565             NaN  best_guess
# 3566             NaN  best_guess
# 3567             NaN  best_guess
# 3568             NaN  best_guess
# 3569             NaN  best_guess
#
# [3570 rows x 24 columns]

# %%
# Use pivot to restructure the DataFrame, we move the data by traffic type from rows to columns
df_Dist_EESS_Final = df_Dist_EESS.pivot(index=['codigo_renaes'], columns='trafic', values=['travel_time', 'travel_distance']).reset_index()

# %%
# We adjust the name of the variables converted into columns
df_Dist_EESS_Final.columns = df_Dist_EESS_Final.columns.map(lambda x: f'{x[0]}_{x[1]}' if isinstance(x, tuple) else x)
df_Dist_EESS_Final = df_Dist_EESS_Final.rename( columns = { df_Dist_EESS_Final.columns[ 0 ] : 'codigo_renaes' } )
df_Dist_EESS_Final
# Out:
#       codigo_renaes  travel_time_best_guess  travel_time_optimistic  \
# 0            4210.0                     NaN                     NaN
# 1            4211.0                     NaN                     NaN
# 2            4212.0                     NaN                     NaN
# 3            4213.0                     NaN                     NaN
# 4            4214.0                     NaN                     NaN
# ...             ...                     ...                     ...
# 1185        30284.0                     NaN                     NaN
# 1186        30291.0                     NaN                     NaN
# 1187        30373.0                     NaN                     NaN
# 1188        30455.0                     NaN                     NaN
# 1189        30456.0                     NaN                     NaN
#
#       travel_time_pessimistic  travel_distance_best_guess  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# ...                       ...                         ...
# 1185                      NaN                         NaN
# 1186                      NaN                         NaN
# 1187                      NaN                         NaN
# 1188                      NaN                         NaN
# 1189                      NaN                         NaN
#
#       travel_distance_optimistic  travel_distance_pessimistic
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 1185                         NaN                          NaN
# 1186                         NaN                          NaN
# 1187                         NaN                          NaN
# 1188                         NaN                          NaN
# 1189                         NaN                          NaN
#
# [1190 rows x 7 columns]

# %%
# From the original data, we only keep one column with the data of the health centers to make the merge
columnas_a_eliminar = ['travel_time', 'travel_distance', 'trafic']
df_Dist_EESS_F = df_Dist_EESS.drop(columns=columnas_a_eliminar)
df_Dist_EESS_F = df_Dist_EESS_F.drop_duplicates()
df_Dist_EESS_F
# Out:
#       id_eess  codigo_renaes categoria          nombre     diresa         red  \
# 0       13172         4553.0       I-2        GUZMANGO  CAJAMARCA   CONTUMAZA
# 1        5348         4554.0       I-2      TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       18927         4540.0       I-1        EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       13899         4573.0       I-2      LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       21765         4575.0       I-2        EL PRADO  CAJAMARCA  SAN MIGUEL
# ...       ...            ...       ...             ...        ...         ...
# 1185    24913         5016.0       I-1        PANDALLE  CAJAMARCA      SOCOTA
# 1186    10080         5018.0       I-1        EL PALTO  CAJAMARCA      SOCOTA
# 1187    13036         5024.0       I-1      LANCHEPATA  CAJAMARCA      SOCOTA
# 1188    13500         6867.0       I-1  LIBERTAD LIMON  CAJAMARCA      SOCOTA
# 1189    24108        11068.0       I-1          PUCALA  CAJAMARCA      SOCOTA
#
#                                               direccion   longitud   latitud  \
# 0     JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1     OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2     OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3     OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                     DISTRITO EL PRADO -79.009410 -7.033193
# ...                                                 ...        ...       ...
# 1185  OTROS COMUNIDAD DE PANDALLE DISTRITO PIMPINGOS... -78.798570 -6.102590
# 1186  OTROS CASERIO EL PALTO S/N NÚMERO S/N DISTRITO... -78.753974 -6.108966
# 1187  OTROS COMUNIDAD LANCHEPATA DISTRITO SANTO TOMA... -78.726498 -6.122737
# 1188  OTROS COMUNIDAD LIBERTAD LIMON COMUNIDAD LIBER... -78.806574 -6.073939
# 1189  OTROS CPM PUCALA DISTRITO PIMPINGOS PROVINCIA ... -78.763947 -6.122548
#
#       id_ubigeo  ...  CCDD    NOMBDEP CCPP    NOMBPROV CCDI   NOMBDIST  \
# 0           613  ...     6  CAJAMARCA    5   CONTUMAZA    4   GUZMANGO
# 1           613  ...     6  CAJAMARCA    5   CONTUMAZA    4   GUZMANGO
# 2           666  ...     6  CAJAMARCA   11  SAN MIGUEL    5   EL PRADO
# 3           666  ...     6  CAJAMARCA   11  SAN MIGUEL    5   EL PRADO
# 4           666  ...     6  CAJAMARCA   11  SAN MIGUEL    5   EL PRADO
# ...         ...  ...   ...        ...  ...         ...  ...        ...
# 1185        623  ...     6  CAJAMARCA    6     CUTERVO    6  PIMPINGOS
# 1186        623  ...     6  CAJAMARCA    6     CUTERVO    6  PIMPINGOS
# 1187        630  ...     6  CAJAMARCA    6     CUTERVO    6  PIMPINGOS
# 1188        623  ...     6  CAJAMARCA    6     CUTERVO    6  PIMPINGOS
# 1189        623  ...     6  CAJAMARCA    6     CUTERVO    6  PIMPINGOS
#
#         CAPITAL   District Dist_Centroid_Longitude  Dist_Centroid_Latitude
# 0      GUZMANGO   GUZMANGO              -78.917689               -7.364304
# 1      GUZMANGO   GUZMANGO              -78.917689               -7.364304
# 2      EL PRADO   EL PRADO              -79.003318               -7.038039
# 3      EL PRADO   EL PRADO              -79.003318               -7.038039
# 4      EL PRADO   EL PRADO              -79.003318               -7.038039
# ...         ...        ...                     ...                     ...
# 1185  PIMPINGOS  PIMPINGOS              -78.768292               -6.070895
# 1186  PIMPINGOS  PIMPINGOS              -78.768292               -6.070895
# 1187  PIMPINGOS  PIMPINGOS              -78.768292               -6.070895
# 1188  PIMPINGOS  PIMPINGOS              -78.768292               -6.070895
# 1189  PIMPINGOS  PIMPINGOS              -78.768292               -6.070895
#
# [1190 rows x 21 columns]

# %%
# We do the final merge with the data column by type of traffic by health establishment
Df_final = pd.merge(df_Dist_EESS_F, df_Dist_EESS_Final, on=['codigo_renaes'], how='inner')
Df_final
# Out:
#       id_eess  codigo_renaes categoria          nombre     diresa         red  \
# 0       13172         4553.0       I-2        GUZMANGO  CAJAMARCA   CONTUMAZA
# 1        5348         4554.0       I-2      TOTORILLAS  CAJAMARCA   CONTUMAZA
# 2       18927         4540.0       I-1        EL GUAYO  CAJAMARCA  SAN MIGUEL
# 3       13899         4573.0       I-2      LAMASPAMPA  CAJAMARCA  SAN MIGUEL
# 4       21765         4575.0       I-2        EL PRADO  CAJAMARCA  SAN MIGUEL
# ...       ...            ...       ...             ...        ...         ...
# 1185    24913         5016.0       I-1        PANDALLE  CAJAMARCA      SOCOTA
# 1186    10080         5018.0       I-1        EL PALTO  CAJAMARCA      SOCOTA
# 1187    13036         5024.0       I-1      LANCHEPATA  CAJAMARCA      SOCOTA
# 1188    13500         6867.0       I-1  LIBERTAD LIMON  CAJAMARCA      SOCOTA
# 1189    24108        11068.0       I-1          PUCALA  CAJAMARCA      SOCOTA
#
#                                               direccion   longitud   latitud  \
# 0     JIRÓN JR. SUAREZ S/N NÚMERO S/N DISTRITO GUZMA... -78.896798 -7.384092
# 1     OTROS CASERIO DE TOTORILLAS DISTRITO GUZMANGO ... -78.930011 -7.353468
# 2     OTROS COMUNIDAD EL GUAYO DISTRITO EL PRADO PRO... -79.010525 -7.101318
# 3     OTROS LOCALIDAD LAMASPAMPA DISTRITO EL PRADO P... -78.985870 -7.104470
# 4                                     DISTRITO EL PRADO -79.009410 -7.033193
# ...                                                 ...        ...       ...
# 1185  OTROS COMUNIDAD DE PANDALLE DISTRITO PIMPINGOS... -78.798570 -6.102590
# 1186  OTROS CASERIO EL PALTO S/N NÚMERO S/N DISTRITO... -78.753974 -6.108966
# 1187  OTROS COMUNIDAD LANCHEPATA DISTRITO SANTO TOMA... -78.726498 -6.122737
# 1188  OTROS COMUNIDAD LIBERTAD LIMON COMUNIDAD LIBER... -78.806574 -6.073939
# 1189  OTROS CPM PUCALA DISTRITO PIMPINGOS PROVINCIA ... -78.763947 -6.122548
#
#       id_ubigeo  ...    CAPITAL   District Dist_Centroid_Longitude  \
# 0           613  ...   GUZMANGO   GUZMANGO              -78.917689
# 1           613  ...   GUZMANGO   GUZMANGO              -78.917689
# 2           666  ...   EL PRADO   EL PRADO              -79.003318
# 3           666  ...   EL PRADO   EL PRADO              -79.003318
# 4           666  ...   EL PRADO   EL PRADO              -79.003318
# ...         ...  ...        ...        ...                     ...
# 1185        623  ...  PIMPINGOS  PIMPINGOS              -78.768292
# 1186        623  ...  PIMPINGOS  PIMPINGOS              -78.768292
# 1187        630  ...  PIMPINGOS  PIMPINGOS              -78.768292
# 1188        623  ...  PIMPINGOS  PIMPINGOS              -78.768292
# 1189        623  ...  PIMPINGOS  PIMPINGOS              -78.768292
#
#       Dist_Centroid_Latitude travel_time_best_guess  travel_time_optimistic  \
# 0                  -7.364304                    NaN                     NaN
# 1                  -7.364304                    NaN                     NaN
# 2                  -7.038039                    NaN                     NaN
# 3                  -7.038039                    NaN                     NaN
# 4                  -7.038039                    NaN                     NaN
# ...                      ...                    ...                     ...
# 1185               -6.070895                    NaN                     NaN
# 1186               -6.070895                    NaN                     NaN
# 1187               -6.070895                    NaN                     NaN
# 1188               -6.070895                    NaN                     NaN
# 1189               -6.070895                    NaN                     NaN
#
#      travel_time_pessimistic travel_distance_best_guess  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 1185                     NaN                        NaN
# 1186                     NaN                        NaN
# 1187                     NaN                        NaN
# 1188                     NaN                        NaN
# 1189                     NaN                        NaN
#
#      travel_distance_optimistic  travel_distance_pessimistic
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 1185                        NaN                          NaN
# 1186                        NaN                          NaN
# 1187                        NaN                          NaN
# 1188                        NaN                          NaN
# 1189                        NaN                          NaN
#
# [1190 rows x 27 columns]

# %% [markdown]
# ## Part II
#
# Plot the following graphs using the final data frame:
#
# 6. Make a histogram of travel time colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province..
# 7. Make a histogram of travel distance colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.
# 8. Bar plot of the mean travel distance by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.
# 9. Bar plot of the mean travel time by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.
#
# Use this data for the following plot.
#
# 10. Make a count plot of the number of health establishments by Department colored by hue = categoria. The x-axis should be the Department Name.

# %% [markdown]
# ### 6. Make a histogram of travel time colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.

# %%
# Apply melt to reshape long
df_long = pd.melt(Df_final, id_vars=['NOMBPROV'], var_name='traffic_model', value_name='travel_time')

# Filter the columns you want to keep
df_long = df_long[df_long['traffic_model'].isin(['travel_time_best_guess', 'travel_time_optimistic', 'travel_time_pessimistic'])]
df_long['traffic_model'] = df_long['traffic_model'].str.replace('travel_time_', '')
df_long
# Out:
#          NOMBPROV traffic_model travel_time
# 23800   CONTUMAZA    best_guess         NaN
# 23801   CONTUMAZA    best_guess         NaN
# 23802  SAN MIGUEL    best_guess         NaN
# 23803  SAN MIGUEL    best_guess         NaN
# 23804  SAN MIGUEL    best_guess         NaN
# ...           ...           ...         ...
# 27365     CUTERVO   pessimistic         NaN
# 27366     CUTERVO   pessimistic         NaN
# 27367     CUTERVO   pessimistic         NaN
# 27368     CUTERVO   pessimistic         NaN
# 27369     CUTERVO   pessimistic         NaN
#
# [3570 rows x 3 columns]

# %%
# Usar groupby y sum para realizar el collapse
result = df_long.groupby(['NOMBPROV', 'traffic_model'])['travel_time'].sum().reset_index()
result['travel_time'] = result['travel_time'].div(60)
result
# Out:
#        NOMBPROV traffic_model travel_time
# 0     CAJABAMBA    best_guess         0.0
# 1     CAJABAMBA    optimistic         0.0
# 2     CAJABAMBA   pessimistic         0.0
# 3     CAJAMARCA    best_guess         0.0
# 4     CAJAMARCA    optimistic         0.0
# 5     CAJAMARCA   pessimistic         0.0
# 6      CELENDIN    best_guess         0.0
# 7      CELENDIN    optimistic         0.0
# 8      CELENDIN   pessimistic         0.0
# 9         CHOTA    best_guess         0.0
# 10        CHOTA    optimistic         0.0
# 11        CHOTA   pessimistic         0.0
# 12    CONTUMAZA    best_guess         0.0
# 13    CONTUMAZA    optimistic         0.0
# 14    CONTUMAZA   pessimistic         0.0
# 15      CUTERVO    best_guess         0.0
# 16      CUTERVO    optimistic         0.0
# 17      CUTERVO   pessimistic         0.0
# 18    HUALGAYOC    best_guess         0.0
# 19    HUALGAYOC    optimistic         0.0
# 20    HUALGAYOC   pessimistic         0.0
# 21         JAEN    best_guess         0.0
# 22         JAEN    optimistic         0.0
# 23         JAEN   pessimistic         0.0
# 24  SAN IGNACIO    best_guess         0.0
# 25  SAN IGNACIO    optimistic         0.0
# 26  SAN IGNACIO   pessimistic         0.0
# 27   SAN MARCOS    best_guess         0.0
# 28   SAN MARCOS    optimistic         0.0
# 29   SAN MARCOS   pessimistic         0.0
# 30   SAN MIGUEL    best_guess         0.0
# 31   SAN MIGUEL    optimistic         0.0
# 32   SAN MIGUEL   pessimistic         0.0
# 33    SAN PABLO    best_guess         0.0
# 34    SAN PABLO    optimistic         0.0
# 35    SAN PABLO   pessimistic         0.0
# 36   SANTA CRUZ    best_guess         0.0
# 37   SANTA CRUZ    optimistic         0.0
# 38   SANTA CRUZ   pessimistic         0.0

# %%
fig, ax = plt.subplots(figsize=(10,6))

# hue: variable descomposition

ax = sns.barplot(x='NOMBPROV', y="travel_time", hue="traffic_model", linewidth=1, data=result, ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

plt.title('Tiempo de viaje por tipo de trafico desde los centros de los distritos a cada EESS para cada Provincia')
plt.xlabel('Provincias de cajamarca')
plt.ylabel('Tiempo (minutos)')
txt="Fuente: Elaboración propia - MINSA"  
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)
# Out:
# C:\Users\U S U A R I O\AppData\Local\Temp\ipykernel_16588\2953276144.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='NOMBPROV', y="travel_time", hue="traffic_model", linewidth=1, data=result, ci=None)
# Text(0.01, -0.1, 'Fuente: Elaboración propia - MINSA')

# %%
# Create a FacetGrid with a barplot for each province
g = sns.FacetGrid(result, col='NOMBPROV', col_wrap=4, height=4, sharey=False)
g.map(sns.barplot, 'traffic_model', 'travel_time', ci=None, palette='viridis')

# Customize the layout
g.set_axis_labels('Traffic Model', 'Time (minutes)')
g.set_titles('Province: {col_name}')
g.fig.suptitle('Distribution of travel time by traffic type for each Province', y=1.02)

# Show the plot
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# El siguiente plot solo es una propuesta.

# %%
sns.displot( data = df_long, x = 'travel_time', 
            kind = 'hist', col = 'NOMBPROV', 
            col_wrap = 3, 
            facet_kws = {'sharex' : False, 
                        'sharey' : False }, 
            hue = 'traffic_model'
           )

# %% [markdown]
# ### 7. Make a histogram of travel distance colored by hue = traffic_model (best_guess, pessimistic, and optimistic) for each Province.

# %%
# Aplicar melt para reshape long
df_dist = pd.melt(Df_final, id_vars=['NOMBPROV'], var_name='traffic_model', value_name='travel_distance')

# Filtrar las columnas que deseas conservar
df_dist = df_dist[df_dist['traffic_model'].isin(['travel_distance_best_guess', 'travel_distance_optimistic', 'travel_distance_pessimistic'])]
df_dist['traffic_model'] = df_dist['traffic_model'].str.replace('travel_distance_', '')
df_dist
# Out:
#          NOMBPROV traffic_model travel_distance
# 27370   CONTUMAZA    best_guess         15542.0
# 27371   CONTUMAZA    best_guess          1338.0
# 27372  SAN MIGUEL    best_guess         22527.0
# 27373  SAN MIGUEL    best_guess             NaN
# 27374  SAN MIGUEL    best_guess          2605.0
# ...           ...           ...             ...
# 30935     CUTERVO   pessimistic         18246.0
# 30936     CUTERVO   pessimistic          9702.0
# 30937     CUTERVO   pessimistic         19093.0
# 30938     CUTERVO   pessimistic         21018.0
# 30939     CUTERVO   pessimistic         13060.0
#
# [3570 rows x 3 columns]

# %%
sns.displot( data = df_dist, x = 'travel_distance', 
            kind = 'hist', col = 'NOMBPROV', 
            col_wrap = 3, 
            facet_kws = {'sharex' : False, 
                        'sharey' : False }, 
            hue = 'traffic_model'
           )

# %% [markdown]
# ### 8. Bar plot of the mean travel distance by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.

# %%
# Usar groupby y sum para realizar el collapse
mean_dist = df_dist.groupby(['NOMBPROV', 'traffic_model'])['travel_distance'].mean().reset_index()
mean_dist
# Out:
#        NOMBPROV traffic_model travel_distance
# 0     CAJABAMBA    best_guess    20273.896552
# 1     CAJABAMBA    optimistic    20273.896552
# 2     CAJABAMBA   pessimistic    20273.896552
# 3     CAJAMARCA    best_guess    16115.041152
# 4     CAJAMARCA    optimistic    16112.506173
# 5     CAJAMARCA   pessimistic    16112.506173
# 6      CELENDIN    best_guess    19098.629032
# 7      CELENDIN    optimistic    19098.629032
# 8      CELENDIN   pessimistic    19098.629032
# 9         CHOTA    best_guess    14970.853933
# 10        CHOTA    optimistic    14970.853933
# 11        CHOTA   pessimistic    14970.853933
# 12    CONTUMAZA    best_guess    26776.789474
# 13    CONTUMAZA    optimistic    26776.789474
# 14    CONTUMAZA   pessimistic    26776.789474
# 15      CUTERVO    best_guess    17726.318182
# 16      CUTERVO    optimistic    17726.318182
# 17      CUTERVO   pessimistic    17726.318182
# 18    HUALGAYOC    best_guess    19123.830508
# 19    HUALGAYOC    optimistic    19123.830508
# 20    HUALGAYOC   pessimistic    19123.830508
# 21         JAEN    best_guess    23432.211921
# 22         JAEN    optimistic    23432.211921
# 23         JAEN   pessimistic    23432.211921
# 24  SAN IGNACIO    best_guess    27940.979592
# 25  SAN IGNACIO    optimistic    27940.979592
# 26  SAN IGNACIO   pessimistic    27940.979592
# 27   SAN MARCOS    best_guess    36095.730769
# 28   SAN MARCOS    optimistic    36095.730769
# 29   SAN MARCOS   pessimistic    36095.730769
# 30   SAN MIGUEL    best_guess    17397.020408
# 31   SAN MIGUEL    optimistic    17397.020408
# 32   SAN MIGUEL   pessimistic    17397.020408
# 33    SAN PABLO    best_guess    14757.071429
# 34    SAN PABLO    optimistic    14757.071429
# 35    SAN PABLO   pessimistic    14757.071429
# 36   SANTA CRUZ    best_guess    10959.657143
# 37   SANTA CRUZ    optimistic    10959.657143
# 38   SANTA CRUZ   pessimistic    10959.657143

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax = sns.barplot(x='NOMBPROV', y="travel_distance", hue="traffic_model", linewidth=1, data=df_dist, ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

plt.title('Distancia por tipo de trafico desde los centros de los distritos a cada EESS para cada Provincia')
plt.xlabel('Provincias de cajamarca')
plt.ylabel('Distancia')
txt="Fuente: Elaboración propia - MINSA"  
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\2461024415.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='NOMBPROV', y="travel_distance", hue="traffic_model", linewidth=1, data=df_dist, ci=None)
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\2461024415.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')
# Text(0.01, -0.1, 'Fuente: Elaboración propia - MINSA')

# %% [markdown]
# ### 9. Bar plot of the mean travel time by Province colored by hue = traffic_model (best_guess, pessimistic, and optimistic). The x-axis should be the name of the Province.

# %%
# Selecciona las columnas relevantes
columns_to_plot = ['NOMBPROV', 'travel_time_best_guess', 'travel_time_optimistic', 'travel_time_pessimistic']
df_plot = Df_final[columns_to_plot]

# Calcula el tiempo medio de viaje por provincia
result = df_plot.groupby('NOMBPROV').mean().reset_index()

# Convierte el DataFrame a un formato largo (long format) para Seaborn
df_plot_long = result.melt(id_vars='NOMBPROV', var_name='traffic_model', value_name='travel_time')
df_plot_long ['traffic_model'] = df_plot_long['traffic_model'].str.replace('travel_time_', '')
df_plot_long
# Out:
#        NOMBPROV traffic_model  travel_time
# 0     CAJABAMBA    best_guess  2986.275862
# 1     CAJAMARCA    best_guess  2411.041152
# 2      CELENDIN    best_guess  2796.532258
# 3         CHOTA    best_guess  2177.870787
# 4     CONTUMAZA    best_guess  2884.842105
# 5       CUTERVO    best_guess  2275.629870
# 6     HUALGAYOC    best_guess  2600.440678
# 7          JAEN    best_guess  2965.761589
# 8   SAN IGNACIO    best_guess  2937.387755
# 9    SAN MARCOS    best_guess  4717.346154
# 10   SAN MIGUEL    best_guess  2514.061224
# 11    SAN PABLO    best_guess  2112.928571
# 12   SANTA CRUZ    best_guess  1705.085714
# 13    CAJABAMBA    optimistic  3002.862069
# 14    CAJAMARCA    optimistic  2476.106996
# 15     CELENDIN    optimistic  2831.354839
# 16        CHOTA    optimistic  2199.758427
# 17    CONTUMAZA    optimistic  2913.210526
# 18      CUTERVO    optimistic  2305.389610
# 19    HUALGAYOC    optimistic  2683.067797
# 20         JAEN    optimistic  3014.410596
# 21  SAN IGNACIO    optimistic  2968.857143
# 22   SAN MARCOS    optimistic  4723.115385
# 23   SAN MIGUEL    optimistic  2547.367347
# 24    SAN PABLO    optimistic  2117.142857
# 25   SANTA CRUZ    optimistic  1705.085714
# 26    CAJABAMBA   pessimistic  3004.586207
# 27    CAJAMARCA   pessimistic  2681.851852
# 28     CELENDIN   pessimistic  2831.354839
# 29        CHOTA   pessimistic  2200.707865
# 30    CONTUMAZA   pessimistic  2942.947368
# 31      CUTERVO   pessimistic  2307.227273
# 32    HUALGAYOC   pessimistic  2683.067797
# 33         JAEN   pessimistic  3027.456954
# 34  SAN IGNACIO   pessimistic  2968.857143
# 35   SAN MARCOS   pessimistic  4746.346154
# 36   SAN MIGUEL   pessimistic  2547.510204
# 37    SAN PABLO   pessimistic  2118.000000
# 38   SANTA CRUZ   pessimistic  1705.085714

# %%
# Crea el Bar Plot
plt.figure(figsize=(10, 6))

ax = sns.barplot(x='NOMBPROV', y='travel_time', hue='traffic_model', linewidth=1, data=df_plot_long, ci=None)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

plt.title('Tiempo Medio de Viaje por tipo de trafico desde los centros de los distritos a cada EESS para cada Provincia')
plt.xlabel('Provincias de Cajamarca')
plt.ylabel('Tiempo Medio de Viaje')
txt="Fuente: Elaboración propia - MINSA"  
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)
plt.show()
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\1451135120.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='NOMBPROV', y='travel_time', hue='traffic_model', linewidth=1, data=df_plot_long, ci=None)
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\1451135120.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

# %% [markdown]
# - El análisis del gráfico revela que los tiempos de viaje promedio desde los centros de los distritos hacia cada Establecimiento de Salud (EESS) en las provincias de Cajamarca, considerando los tres tipos de tráfico (best guess, optimistic, pessimistic), son notablemente similares. En todos los casos, se observa una ligera mejora en los tiempos para el escenario "best guess". Sin embargo, cabe destacar que la provincia de San Marcos destaca al presentar los tiempos de viaje más prolongados en los tres tipos de tráfico, evidenciando ser la provincia con mayores distancias para llegar a los EESS en el departamento de Cajamarca.
# -
# Esta disparidad en los tiempos de viaje se vincula directamente con las distancias, ya que San Marcos exhibe distancias más extensas en comparación con otras provincias. En contraste, la provincia de Santa Cruz se distingue al tener los tiempos de viaje más cortos, siendo incluso menos de la mitad de los tiempos registrados en San Marcos. Este fenómeno también guarda relación con las distancias, ya que Santa Cruz presenta distancias promedio más reducidas para acceder a sus EESS. Estos hallazgos resaltan la influencia directa que la geografía y la distribución de los establecimientos tienen en los tiempos de viaje en el contexto de sla provincsia de Cajamarca.

# %% [markdown]
# ### 10. Make a count plot of the number of health establishments by Department colored by hue = categoria. The x-axis should be the Department Name.

# %% [markdown]
# #### 10.1 Getting the necessary file

# %%
# Getting the files from the "_data" folder 
file1_path = r"../../_data/salud_places_peru.csv" 

# Creating Data Frames
df_salud_places = pd.read_csv(file1_path, sep=',')

# Show the DataFrame
df_salud_places
# Out:
#        id_eess  codigo_renaes categoria  \
# 0         5845              1      II-2
# 1        15599              2        SD
# 2        18282              3     III-1
# 3        18156              4       I-3
# 4          858              5       I-1
# ...        ...            ...       ...
# 28837    20228        9999164       I-3
# 28838     4292        9999165       I-3
# 28839     5423        9999166       I-3
# 28840    28694        9999167       I-3
# 28841    21087        9999168       I-3
#
#                                                   nombre  diresa  \
# 0                HOSPITAL IQUITOS "CESAR GARAYAR GARCIA"  LORETO
# 1                   CENTRO REHABILITACION ENFERMO MENTAL  LORETO
# 2      HOSPITAL REGIONAL DE LORETO "FELIPE SANTIAGO A...  LORETO
# 3                          C.S. I-3 SANTA MARIA DE NANAY  LORETO
# 4                                                 SAMITO  LORETO
# ...                                                  ...     ...
# 28837  CENTRO DE SALUD MENTAL COMUNITARIO "SAN ISIDRO...    PUNO
# 28838  CENTRO DE  SALUD MENTAL COMUNITARIO "LA CAPILL...    PUNO
# 28839  CENTRO DE SALUD MENTAL COMUNITARIO "SAN MIGUEL...    PUNO
# 28840        CENTRO DE SALUD MENTAL COMUNITARIO "CALLAO"  CALLAO
# 28841  CENTRO DE SALUD MENTAL COMUNITARIO "VILLA LOS ...  CALLAO
#
#                               red  \
# 0      NO PERTENECE A NINGUNA RED
# 1      NO PERTENECE A NINGUNA RED
# 2      NO PERTENECE A NINGUNA RED
# 3                   MAYNAS CIUDAD
# 4                   MAYNAS CIUDAD
# ...                           ...
# 28837  NO PERTENECE A NINGUNA RED
# 28838  NO PERTENECE A NINGUNA RED
# 28839  NO PERTENECE A NINGUNA RED
# 28840  NO PERTENECE A NINGUNA RED
# 28841  NO PERTENECE A NINGUNA RED
#
#                                                direccion   longitud   latitud  \
# 0      CALLE CORNEJO PORTUGAL 1710 IQUITOS MAYNAS LORETO -73.253653 -3.762818
# 1                    CALLE 3 DE MAYO S/N CPM QUILCATACTA -73.323250 -3.731890
# 2      AVENIDA AVENIDA 28 DE JULIO S/N S/N AVENIDA 28... -73.253417 -3.726960
# 3      OTROS CASERIO DE SANTA MARIA DE NANAY CASERIO ... -73.696785 -3.888998
# 4      OTROS CASERIO DE SAMITO SIN NUMERO DISTRITO AL... -73.610928 -3.865167
# ...                                                  ...        ...       ...
# 28837                                                NaN   0.000000  0.000000
# 28838                                                NaN   0.000000  0.000000
# 28839                                                NaN   0.000000  0.000000
# 28840                                                NaN   0.000000  0.000000
# 28841                                                NaN   0.000000  0.000000
#
#        id_ubigeo
# 0           1453
# 1           1463
# 2           1460
# 3           1454
# 4           1454
# ...          ...
# 28837       1719
# 28838       1719
# 28839       1719
# 28840        690
# 28841        695
#
# [28842 rows x 10 columns]

# %% [markdown]
# #### 10.2 Analizando la data

# %%
# Shows the unique values of the variable "diresa"
df_salud_places.diresa.unique()
# Out:
# array(['LORETO', 'JUNIN', 'HUANUCO', 'PASCO', 'AREQUIPA', 'ANCASH',
#        'TUMBES', 'PIURA', 'CUSCO', 'APURIMAC', 'MADRE DE DIOS',
#        'MOQUEGUA', 'TACNA', 'PUNO', 'ICA', 'AYACUCHO', 'HUANCAVELICA',
#        'CAJAMARCA', 'LAMBAYEQUE', 'AMAZONAS', 'LA LIBERTAD', 'UCAYALI',
#        'LIMA PROVINCIAS', 'LIMA DIRIS CENTRO', 'LIMA DIRIS NORTE',
#        'LIMA DIRIS ESTE', 'LIMA DIRIS SUR', 'CALLAO', 'SAN MARTIN'],
#       dtype=object)

# %%
# Change specific values
df_salud_places['diresa'].replace({
    'LIMA PROVINCIAS': 'LIMA',
    'LIMA DIRIS CENTRO': 'LIMA',
    'LIMA DIRIS NORTE': 'LIMA',
    'LIMA DIRIS ESTE': 'LIMA',
    'LIMA DIRIS SUR': 'LIMA',
    'CALLAO': 'LIMA'
}, inplace=True)
df_salud_places.diresa.unique()
# Out:
# array(['LORETO', 'JUNIN', 'HUANUCO', 'PASCO', 'AREQUIPA', 'ANCASH',
#        'TUMBES', 'PIURA', 'CUSCO', 'APURIMAC', 'MADRE DE DIOS',
#        'MOQUEGUA', 'TACNA', 'PUNO', 'ICA', 'AYACUCHO', 'HUANCAVELICA',
#        'CAJAMARCA', 'LAMBAYEQUE', 'AMAZONAS', 'LA LIBERTAD', 'UCAYALI',
#        'LIMA', 'SAN MARTIN'], dtype=object)

# %%
# Change the name of the 'diresa' column to'Departamento' 
df_salud_places.rename(columns={'diresa': 'departamento'}, inplace=True)
df_salud_places
# Out:
#        id_eess  codigo_renaes categoria  \
# 0         5845              1      II-2
# 1        15599              2        SD
# 2        18282              3     III-1
# 3        18156              4       I-3
# 4          858              5       I-1
# ...        ...            ...       ...
# 28837    20228        9999164       I-3
# 28838     4292        9999165       I-3
# 28839     5423        9999166       I-3
# 28840    28694        9999167       I-3
# 28841    21087        9999168       I-3
#
#                                                   nombre departamento  \
# 0                HOSPITAL IQUITOS "CESAR GARAYAR GARCIA"       LORETO
# 1                   CENTRO REHABILITACION ENFERMO MENTAL       LORETO
# 2      HOSPITAL REGIONAL DE LORETO "FELIPE SANTIAGO A...       LORETO
# 3                          C.S. I-3 SANTA MARIA DE NANAY       LORETO
# 4                                                 SAMITO       LORETO
# ...                                                  ...          ...
# 28837  CENTRO DE SALUD MENTAL COMUNITARIO "SAN ISIDRO...         PUNO
# 28838  CENTRO DE  SALUD MENTAL COMUNITARIO "LA CAPILL...         PUNO
# 28839  CENTRO DE SALUD MENTAL COMUNITARIO "SAN MIGUEL...         PUNO
# 28840        CENTRO DE SALUD MENTAL COMUNITARIO "CALLAO"         LIMA
# 28841  CENTRO DE SALUD MENTAL COMUNITARIO "VILLA LOS ...         LIMA
#
#                               red  \
# 0      NO PERTENECE A NINGUNA RED
# 1      NO PERTENECE A NINGUNA RED
# 2      NO PERTENECE A NINGUNA RED
# 3                   MAYNAS CIUDAD
# 4                   MAYNAS CIUDAD
# ...                           ...
# 28837  NO PERTENECE A NINGUNA RED
# 28838  NO PERTENECE A NINGUNA RED
# 28839  NO PERTENECE A NINGUNA RED
# 28840  NO PERTENECE A NINGUNA RED
# 28841  NO PERTENECE A NINGUNA RED
#
#                                                direccion   longitud   latitud  \
# 0      CALLE CORNEJO PORTUGAL 1710 IQUITOS MAYNAS LORETO -73.253653 -3.762818
# 1                    CALLE 3 DE MAYO S/N CPM QUILCATACTA -73.323250 -3.731890
# 2      AVENIDA AVENIDA 28 DE JULIO S/N S/N AVENIDA 28... -73.253417 -3.726960
# 3      OTROS CASERIO DE SANTA MARIA DE NANAY CASERIO ... -73.696785 -3.888998
# 4      OTROS CASERIO DE SAMITO SIN NUMERO DISTRITO AL... -73.610928 -3.865167
# ...                                                  ...        ...       ...
# 28837                                                NaN   0.000000  0.000000
# 28838                                                NaN   0.000000  0.000000
# 28839                                                NaN   0.000000  0.000000
# 28840                                                NaN   0.000000  0.000000
# 28841                                                NaN   0.000000  0.000000
#
#        id_ubigeo
# 0           1453
# 1           1463
# 2           1460
# 3           1454
# 4           1454
# ...          ...
# 28837       1719
# 28838       1719
# 28839       1719
# 28840        690
# 28841        695
#
# [28842 rows x 10 columns]

# %%
# Reorganize the DataFrame to count the number of establishments by department and category
df_count = df_salud_places.groupby(['departamento', 'categoria']).size().reset_index(name='count')
df_count
# Out:
#     departamento categoria  count
# 0       AMAZONAS       I-1    415
# 1       AMAZONAS       I-2     80
# 2       AMAZONAS       I-3    114
# 3       AMAZONAS       I-4      4
# 4       AMAZONAS      II-1      8
# ..           ...       ...    ...
# 195      UCAYALI       I-4      7
# 196      UCAYALI      II-1      1
# 197      UCAYALI      II-2      3
# 198      UCAYALI      II-E      1
# 199      UCAYALI        SD     46
#
# [200 rows x 3 columns]

# %% [markdown]
# #### 10.3 Graphing the data as requested

# %%
# Define the desired order for the categories
orden_categorias = ['I-1', 'I-2', 'I-3', 'I-4', 'II-1', 'II-2', 'II-E', 'III-1', 'III-2', 'III-E','SD']

# Create the Count Plot
plt.figure(figsize=(15, 8))

ax = sns.countplot(x='departamento', hue='categoria', data=df_salud_places,
                  hue_order=orden_categorias,
                  order=df_count.groupby('departamento')['count'].sum().sort_values(ascending=False).index)

# Adjust the size and orientation of x-axis labels to improve readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.title('Número de Establecimientos de Salud por Departamento y Categoría')
plt.xlabel('Departamento')
plt.ylabel('Número de Establecimientos')

# Move the legend to the top, horizontal and centered
ax.legend(title='Categoría', loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=len(df_salud_places['categoria'].unique()))

# Add source
txt="Fuente: Elaboración propia - MINSA" 
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)

# Show the graph
plt.show()
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\113348689.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# - El análisis del gráfico resalta la marcada concentración de Establecimientos de Salud (EESS) en el departamento de Lima en comparación con otros departamentos. En Lima, el número de EESS por categoría supera los 4000, mientras que en los demás departamentos no alcanza los 1000 establecimientos. Se destaca que, independientemente del departamento, las categorías de EESS más prevalentes son los de tipo I-1 (Puesto de salud, posta de salud o consultorio con profesionales de salud no médicos) y los SD (Establecimiento de Salud Diverso), mientras que los EESS de categoría III (hospitales de atención terciaria con servicios altamente especializados) son escasos en todos los departamentos.
#
# - El departamento de Tumbes se posiciona como el que cuenta con el menor número de EESS a nivel nacional, seguido ligeramente por el departamento de Moquegua. Después de Lima, los departamentos con mayor cantidad de EESS son Piura, Cajamarca, Arequipa y Cusco.
#
# - Revisar el siguiente gráfico, donde se excluye al departamento de Lima, para obtener una visión más equitativa de la distribución de los establecimientos en el país. Estos hallazgos subrayan las disparidades significativas en la distribución y disponibilidad de servicios de salud a nivel nacional.

# %%
# Filter the DataFrame excluding the department of Lima
df_salud_places_sin_lima = df_salud_places[df_salud_places['departamento'] != 'LIMA']

# Define the desired order for the categories
orden_categorias = ['I-1', 'I-2', 'I-3', 'I-4', 'II-1', 'II-2', 'II-E', 'III-1', 'III-2', 'III-E', 'SD']

# Create the Count Plot
plt.figure(figsize=(16, 8))

ax = sns.countplot(x='departamento', hue='categoria', data=df_salud_places_sin_lima,
                  hue_order=orden_categorias,
                  order=df_salud_places_sin_lima.groupby('departamento')['categoria'].count().sort_values(ascending=False).index)

# Adjust the size and orientation of x-axis labels to improve readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.title('Número de Establecimientos de Salud por Departamento y Categoría (Excluyendo Lima)')
plt.xlabel('Departamento')
plt.ylabel('Número de Establecimientos')

# Move the legend to the top, horizontal and centered
ax.legend(title='Categoría', loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=len(df_salud_places_sin_lima['categoria'].unique()))

# Add source
txt = "Fuente: Elaboración propia - MINSA"
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)

# Show the graph
plt.show()
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\2150475789.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# #### Applying logarithmic scale on the Y axis to reduce the apparent difference between the extreme values (the department of Lima with respect to the other departments)

# %%
# Reorganize the DataFrame to count the number of establishments by department and category
df_count = df_salud_places.groupby(['departamento', 'categoria']).size().reset_index(name='count')

# Define the desired order for the categories
orden_categorias = ['I-1', 'I-2', 'I-3', 'I-4', 'II-1', 'II-2', 'II-E', 'III-1', 'III-2', 'III-E','SD']

# CCreate a custom color palette
custom_palette = sns.color_palette("husl", n_colors=len(df_salud_places['categoria'].unique()))

# Create the Count Plot using Seaborn with visual settings
plt.figure(figsize=(15, 8))
ax = sns.countplot(x='departamento', hue='categoria', data=df_salud_places, palette='husl',
                    hue_order=orden_categorias,
                   order=df_count.groupby('departamento')['count'].sum().sort_values(ascending=False).index)

# Adjust the size and orientation of x-axis labels to improve readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Scale the y-axis to a logarithmic scale to handle large values
ax.set_yscale('log')

plt.title('Número de Establecimientos de Salud por Departamento y Categoría')
plt.xlabel('Departamento')
plt.ylabel('Número de Establecimientos (escala logarítmica)')

# Move the legend to the top, horizontal and centered
ax.legend(title='Categoría', loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=len(df_salud_places['categoria'].unique()))

# Add source
txt = "Fuente: Elaboración propia - MINSA"
plt.figtext(0.01, -0.1, txt, wrap=True, horizontalalignment='left', va="top", fontsize=10)

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13320\2648333294.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# Al suavizar los datos y escalarlos, se ha logrado una representación más clara del número de establecimientos de salud por departamento. Este nuevo gráfico, similar al primer gráfico, permite apreciar con mayor detalle la distribución de los establecimientos de salud, destacando que los más escasos son los de categoría Nivel III y los Especializados, los cuales incluso parecen no estar presentes en algunos departamentos del país. Contrariamente, los establecimientos de categoría I-1, I-2 y SD son los más prevalentes a nivel nacional. Esta visualización proporciona una perspectiva refinada de la disponibilidad de servicios de salud en diferentes departamentos, resaltando las disparidades en la distribución y especialización de los establecimientos en todo el país.
